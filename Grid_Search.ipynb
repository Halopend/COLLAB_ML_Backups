# %% [markdown]
# # Project Desciption
#
# This mini-project will give you experience with working with text data and machine learning with scikit-learn. You will develop models to analyze text from the website Reddit. Reddit is a popular social media forum where users post and comment on content in different themed communities, or subreddits. The goal is to, given a post or comment from reddit, identify the subreddit where that post or comment originally came from. The dataset is gathered from posts and comments from 8 subreddits:
#
# rpg : Subreddit for tabletop role playing games
# anime : Subreddit for discussing Japanese animation
# datascience : Subreddit for discussing matters related to data science, including machine learning
# hardware : Computer hardware news and discussions
# cars : Discussions and news about cars
# gamernews : Discussing video game related news.
# gamedev : Subreddit for video game developers
# computers : Subreddit for discussing anything about computers.
# Download the training and test data from the Kaggle competition page (details to follow below). Each line in train.csv includes two fields: text of a post/comment, and the subreddit it was posted on. Use train.csv for training your models.
#
# Your tasks
#
# Part 1: using the data provided in train.csv
# Implement Bernoulli Naïve Bayes from scratch. Since your implementation may not be optimized for speed, you can set the max_features=5000 in CountVectorizer(). This will consider only the top 5000 words i.e.  m=5000.
# You need to do additional experiments using at least one additional classifiers from the SciKit learn package (excluding Bernoulli Naïve Bayes). For example Logistic Regression, Decision Tree, etc.
# Implement a model validation (e.g. using k-fold cross-validation) and use it to report, in your write-up, the performance of the above mentioned classification models (i.e., your Naïve Bayes model and the SciKit learn model(s)). You can use KFold from SciKit learn.
# Part 2: run your best model (obtained in Part 1) on the data provided in test.csv and submit the result on Kaggle competition. (See below for more details)
# Part 3: Prepare and submit your report (max 5 pages) along with your codes (details below).
#
# Hint 1: You many want to use Laplace smoothing with your Bernoulli Naïve Bayes model.
# Hint 2: you may use CountVectorizer() with binary=False to obtain a binary vector representation for a text.
# Hint 3: when debugging your code, you might start off by using only a quarter of train samples and a quarter test samples. When you are done with code debugging, apply your code to the complete data.

# %% [markdown]
# # Setup

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

DEBUG = True
KFOLDS_ENABLE = False
SHUFFLE = True

try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    projectDIR='/content/drive/My Drive/School/COMP4900A/COMP4900A-MP2/'
    # !pip install PipelineHelper xgboost catboost

except:
    projectDIR='./'

dataDIR = projectDIR + 'data'

## Training  Data Import
trainCSV = dataDIR + '/dataset/train.csv'
train_df = pd.read_csv(trainCSV)

## Testing Data Import
testCSV = dataDIR + '/dataset/test.csv'
test_df = pd.read_csv(testCSV)


from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle

sub_reddit = ['rpg', 'anime', 'datascience', 'hardware', 'cars', 'gamernews', 'gamedev', 'computers']
le = LabelEncoder()
le.fit(sub_reddit)  ## define the categories le will encode excplicity. Could also extract from data, but this is safer

X = train_df['body']       ## Main corpus is generated from the training set
y = le.transform(train_df['subreddit'])

if SHUFFLE:
    X, y = shuffle(X,y, random_state=27)

# %% [markdown]
# # Custom classes for transforming or cleaning data

# %%
from sklearn.base import TransformerMixin,BaseEstimator

class CleanTextTransformer(TransformerMixin,BaseEstimator):
  def cleanText(self,text):
     text = text.strip().replace("\n", " ").replace("\r", " ")
     text = text.lower()
     return text
  def transform(self, X, **transform_params):
       return [self.cleanText(text) for text in X]
  def fit(self, X, y=None, **fit_params):
       return self
  def get_params(self, deep=True):
          return {}

class BaseBernoulliNB(BaseEstimator):
  def _update_theta(self, x, y, smooth=0.1):
    '''
    x:feature matrix of examples
    y:result matrix of examples
    self.theta_k a 1xk matrix contain all possible yk: (# of examples where y=yk) / (total # of examples)
    self.theta_k_j is a kxj metrix of all possible xj in yk: (# of examples where xj=1 and y=k) / (# of examples where y=k)
    '''
    class_name = np.unique(y, axis=0)
    class_num = len(class_name)
    self.theta_k = np.zeros(class_num)
    self.theta_k_j = np.zeros((class_num, x.shape[1]))
    for k in range (class_num):
      k_num = np.count_nonzero(y == class_name[k], axis=0)
      self.theta_k[k] = k_num / y.shape[0]
      for j in range (x.shape[1]):
        k_j_count = 0
        k_num += 2 * smooth
        k_j_count += smooth
        for i in range (x.shape[0]):
          if y[i] == k:
            k_j_count += x[i][j]
        self.theta_k_j[k][j] = k_j_count / k_num

  def fit(self, x, y, smooth=0.1):
    '''
    self.class_log_prior is a 1xk metrix of log(self.theta_k), k is the number of classes
    self.feature_likelihood_log_one is a kxj metrix of log(self.theta_k_j), k is the number of the classes and j is the features
    self.feature_likelihood_log_one is a kxj metrix of log(self.1 - theta_k_j), k is the number of the classes and j is the features
    '''
    self._update_theta(x, y, smooth)
    self.class_log_prior = np.log(self.theta_k)
    self.feature_likelihood_log_one = np.log(self.theta_k_j)
    self.feature_likelihood_log_zero = np.log(1 - self.theta_k_j)

  def predict(self, x):
    if len(x.shape) ==1:
      y = np.zeros(1)
      class_pro = np.zeros(len(self.class_log_prior))
      for k in range (len(class_pro)):
        class_pro[k] += self.class_log_prior[k] + np.sum(np.multiply(x, self.feature_likelihood_log_one[k].T)) + np.sum(np.multiply(1 - x, self.feature_likelihood_log_zero[k].T))
      y[0] = np.argmax(class_pro)
      return y
    else:
      y = np.zeros(x.shape[0])
      for i in range (x.shape[0]):
        class_pro = np.zeros(len(self.class_log_prior))
        for k in range (len(class_pro)):
          class_pro[k] += self.class_log_prior[k] + np.sum(np.multiply(x[i], self.feature_likelihood_log_one[k].T)) + np.sum(np.multiply(1 - x[i], self.feature_likelihood_log_zero[k].T))
        y[i] = np.argmax(class_pro)
      return y

import tensorflow_hub as hub
import logging, os

logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"                                                ## Suppress tf related warnings, as USE seems to slightly clash with tf version
os.environ["TFHUB_CACHE_DIR"] = projectDIR +'cache'                                     ## This is the ~1GB sentence encoder storage 
class UniversalEncoderVectorizer(TransformerMixin,BaseEstimator):

     def transform(self, X, **transform_params):
          universal_encoder = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4") ### This is an ouchy workaround to parralelization
          universal_X_tensor = universal_encoder(X)
          generated_X = np.asarray(universal_X_tensor)   ### This is the data encoded as a semantic relation rather than tfidf 
          return generated_X

     def fit(self, X, y=None, **fit_params):
          return self

     def get_params(self, deep=True):
          return {}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from pipelinehelper import PipelineHelper

## Vectorizers
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# Plus our UniversalEncoderVectorizer


## Classifiers
from sklearn.svm            import LinearSVC
from sklearn.naive_bayes    import CategoricalNB
from sklearn.linear_model   import LogisticRegression
from sklearn.linear_model   import PassiveAggressiveClassifier
from sklearn.linear_model   import Perceptron
from sklearn.linear_model   import RidgeClassifier

## Ensemble Methods
from sklearn.ensemble       import RandomForestClassifier
from sklearn.ensemble       import GradientBoostingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier


## Selectors
from sklearn.feature_selection import RFE

## Stop Words
from spacy.lang.en.stop_words import STOP_WORDS

tfidf_vect = TfidfVectorizer(stop_words='english',sublinear_tf=True,strip_accents='unicode',ngram_range=(1,1))
unviversal_sentence_encoder = UniversalEncoderVectorizer()

## Note: input is desiged to text into a form compatibile with the classifiers (vectors)
# if using the universal sentence encode, we want to disable the input and combine the vectors
pipe = Pipeline([
    ('input',  PipelineHelper([
        # ('tfidf', tfidf_vect),

        # ('count_vect', CountVectorizer()),

        # ('universal_sentence', unviversal_sentence_encoder),

        ('universal_sentence_tfid',  FeatureUnion([
            ('universal_sentence', unviversal_sentence_encoder),
            ('tfidf', tfidf_vect),
        ])),

    ])),
    ('clf', PipelineHelper([
    #   ('svm',           LinearSVC()),
    #   ('naive_bayes_classfier', BaseBernoulliNB()),      
    #   ('rfc',           RandomForestClassifier()),
    #   ('pac',           PassiveAggressiveClassifier()),
    #   ('percep',        Perceptron()),
    #   ('ridge',         RidgeClassifier()),
      # ('gradientboost', GradientBoostingClassifier()),
      # ('x_gradientboost', XGBClassifier()),
      ('catboost', CatBoostClassifier(task_type="GPU",)),

    ])),
])


parameters = {
    'input__selected_model': pipe.named_steps['input'].generate({}),

    ## pipe.named_steps is how to utilize pipeline helper, which can be used to swap in different 
    ## models/transformers/classed that implement fit/transform for piping
    'clf__selected_model': pipe.named_steps['clf'].generate({
        # 'svm__C': [1.0,],
        # 'ridge__alpha': [1,0.5,0.3],
        # 'ridge__normalize': [False,True],
    }),
}

# pipe = Pipeline([
#     ('pre-process', CleanTextTransformer()),
#     ('combo_vectorizer', FeatureUnion([
#         ('universal_sentence', unviversal_sentence_encoder),
#         ('tfidf', tfidf_vect),
#     ])),     
#     ('clf', PipelineHelper([
#       ('svm',           LinearSVC()),
#       ('rfc',           RandomForestClassifier()),
#       ('pac',           PassiveAggressiveClassifier()),
#       ('percep',        Perceptron()),
#       ('ridge',         RidgeClassifier()),
#       # ('gradientboost', GradientBoostingClassifier()),
#     ])),
# ])


# parameters = {
#     'combo_vectorizer__tfidf__ngram_range': ((1,1),(1,2)),
#     'combo_vectorizer__tfidf__stop_words': (STOP_WORDS,'english',None),

#     ## pipe.named_steps is how to utilize pipeline helper, which can be used to swap in different 
#     ## models/transformers/classed that implement fit/transform for piping
#     'clf__selected_model': pipe.named_steps['clf'].generate({
#         'svm__C': [1.0,],
#         'ridge__alpha': [1,0.5,0.3],
#         'ridge__normalize': [False,True],
#     }),
# }

print('################################################################\n###Buckle your seatbelts cause this is gonna be a long one!!! ###\n')
grid_search = GridSearchCV(pipe, parameters,cv=5, n_jobs=1, verbose=3)
grid_search.fit(X,y)
# Out:
# ################################################################
# ###Buckle your seatbelts cause this is gonna be a long one!!! ###
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] clf__selected_model=('catboost', {}), input__selected_model=('universal_sentence_tfid', {})
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Learning rate set to 0.102216
# Warning: less than 75% gpu memory available for training. Free: 8613.875 Total: 15079.75
# 0:	learn: 1.7698976	total: 374ms	remaining: 6m 13s
# 1:	learn: 1.5640084	total: 572ms	remaining: 4m 45s
# 2:	learn: 1.4156539	total: 753ms	remaining: 4m 10s
# 3:	learn: 1.3046499	total: 938ms	remaining: 3m 53s
# 4:	learn: 1.2093502	total: 1.14s	remaining: 3m 47s
# 5:	learn: 1.1288260	total: 1.33s	remaining: 3m 41s
# 6:	learn: 1.0540714	total: 1.53s	remaining: 3m 37s
# 7:	learn: 0.9968887	total: 1.74s	remaining: 3m 36s
# 8:	learn: 0.9523273	total: 1.92s	remaining: 3m 31s
# 9:	learn: 0.9021853	total: 2.11s	remaining: 3m 29s
# 10:	learn: 0.8584896	total: 2.31s	remaining: 3m 27s
# 11:	learn: 0.8193213	total: 2.5s	remaining: 3m 26s
# 12:	learn: 0.7854707	total: 2.7s	remaining: 3m 25s
# 13:	learn: 0.7542997	total: 2.88s	remaining: 3m 23s
# 14:	learn: 0.7268135	total: 3.08s	remaining: 3m 22s
# 15:	learn: 0.7018701	total: 3.29s	remaining: 3m 22s
# 16:	learn: 0.6796909	total: 3.45s	remaining: 3m 19s
# 17:	learn: 0.6579273	total: 3.64s	remaining: 3m 18s
# 18:	learn: 0.6385789	total: 3.85s	remaining: 3m 18s
# 19:	learn: 0.6195394	total: 4.05s	remaining: 3m 18s
# 20:	learn: 0.6015045	total: 4.25s	remaining: 3m 17s
# 21:	learn: 0.5881840	total: 4.42s	remaining: 3m 16s
# 22:	learn: 0.5734291	total: 4.62s	remaining: 3m 16s
# 23:	learn: 0.5584581	total: 4.83s	remaining: 3m 16s
# 24:	learn: 0.5466771	total: 5s	remaining: 3m 14s
# 25:	learn: 0.5356089	total: 5.18s	remaining: 3m 13s
# 26:	learn: 0.5243257	total: 5.32s	remaining: 3m 11s
# 27:	learn: 0.5135291	total: 5.5s	remaining: 3m 10s
# 28:	learn: 0.5031157	total: 5.67s	remaining: 3m 9s
# 29:	learn: 0.4954318	total: 5.84s	remaining: 3m 8s
# 30:	learn: 0.4902530	total: 5.95s	remaining: 3m 5s
# 31:	learn: 0.4814791	total: 6.14s	remaining: 3m 5s
# 32:	learn: 0.4745046	total: 6.27s	remaining: 3m 3s
# 33:	learn: 0.4692519	total: 6.39s	remaining: 3m 1s
# 34:	learn: 0.4639256	total: 6.53s	remaining: 3m
# 35:	learn: 0.4586599	total: 6.65s	remaining: 2m 58s
# 36:	learn: 0.4515921	total: 6.84s	remaining: 2m 58s
# 37:	learn: 0.4453828	total: 7.04s	remaining: 2m 58s
# 38:	learn: 0.4411065	total: 7.16s	remaining: 2m 56s
# 39:	learn: 0.4355981	total: 7.33s	remaining: 2m 55s
# 40:	learn: 0.4311998	total: 7.51s	remaining: 2m 55s
# 41:	learn: 0.4259130	total: 7.68s	remaining: 2m 55s
# 42:	learn: 0.4204379	total: 7.84s	remaining: 2m 54s
# 43:	learn: 0.4167725	total: 8s	remaining: 2m 53s
# 44:	learn: 0.4129323	total: 8.16s	remaining: 2m 53s
# 45:	learn: 0.4087795	total: 8.31s	remaining: 2m 52s
# 46:	learn: 0.4061480	total: 8.42s	remaining: 2m 50s
# 47:	learn: 0.4016508	total: 8.54s	remaining: 2m 49s
# 48:	learn: 0.3971092	total: 8.71s	remaining: 2m 49s
# 49:	learn: 0.3947470	total: 8.82s	remaining: 2m 47s
# 50:	learn: 0.3928122	total: 8.93s	remaining: 2m 46s
# 51:	learn: 0.3894177	total: 9.04s	remaining: 2m 44s
# 52:	learn: 0.3876381	total: 9.15s	remaining: 2m 43s
# 53:	learn: 0.3859639	total: 9.28s	remaining: 2m 42s
# 54:	learn: 0.3836891	total: 9.39s	remaining: 2m 41s
# 55:	learn: 0.3812048	total: 9.54s	remaining: 2m 40s
# 56:	learn: 0.3779274	total: 9.7s	remaining: 2m 40s
# 57:	learn: 0.3763080	total: 9.8s	remaining: 2m 39s
# 58:	learn: 0.3752548	total: 9.9s	remaining: 2m 37s
# 59:	learn: 0.3743369	total: 10s	remaining: 2m 36s
# 60:	learn: 0.3727827	total: 10.1s	remaining: 2m 35s
# 61:	learn: 0.3723781	total: 10.2s	remaining: 2m 34s
# 62:	learn: 0.3722376	total: 10.3s	remaining: 2m 33s
# 63:	learn: 0.3720326	total: 10.4s	remaining: 2m 31s
# 64:	learn: 0.3711454	total: 10.5s	remaining: 2m 30s
# 65:	learn: 0.3694857	total: 10.6s	remaining: 2m 29s
# 66:	learn: 0.3688661	total: 10.7s	remaining: 2m 28s
# 67:	learn: 0.3667836	total: 10.8s	remaining: 2m 27s
# 68:	learn: 0.3655804	total: 10.9s	remaining: 2m 26s
# 69:	learn: 0.3645864	total: 11s	remaining: 2m 26s
# 70:	learn: 0.3629992	total: 11.1s	remaining: 2m 25s
# 71:	learn: 0.3618428	total: 11.2s	remaining: 2m 24s
# 72:	learn: 0.3599220	total: 11.3s	remaining: 2m 24s
# 73:	learn: 0.3592559	total: 11.4s	remaining: 2m 23s
# 74:	learn: 0.3591730	total: 11.5s	remaining: 2m 22s
# 75:	learn: 0.3566446	total: 11.7s	remaining: 2m 22s
# 76:	learn: 0.3549425	total: 11.8s	remaining: 2m 21s
# 77:	learn: 0.3528905	total: 11.9s	remaining: 2m 20s
# 78:	learn: 0.3526951	total: 12s	remaining: 2m 19s
# 79:	learn: 0.3525047	total: 12.1s	remaining: 2m 18s
# 80:	learn: 0.3524165	total: 12.2s	remaining: 2m 18s
# 81:	learn: 0.3514742	total: 12.3s	remaining: 2m 17s
# 82:	learn: 0.3514162	total: 12.3s	remaining: 2m 16s
# 83:	learn: 0.3498712	total: 12.5s	remaining: 2m 15s
# 84:	learn: 0.3491681	total: 12.6s	remaining: 2m 15s
# 85:	learn: 0.3484252	total: 12.7s	remaining: 2m 14s
# 86:	learn: 0.3471160	total: 12.8s	remaining: 2m 14s
# 87:	learn: 0.3469765	total: 12.9s	remaining: 2m 13s
# 88:	learn: 0.3467800	total: 12.9s	remaining: 2m 12s
# 89:	learn: 0.3455320	total: 13s	remaining: 2m 11s
# 90:	learn: 0.3454689	total: 13.1s	remaining: 2m 11s
# 91:	learn: 0.3454000	total: 13.2s	remaining: 2m 10s
# 92:	learn: 0.3448337	total: 13.3s	remaining: 2m 9s
# 93:	learn: 0.3433735	total: 13.4s	remaining: 2m 9s
# 94:	learn: 0.3431215	total: 13.5s	remaining: 2m 8s
# 95:	learn: 0.3430629	total: 13.6s	remaining: 2m 8s
# 96:	learn: 0.3430340	total: 13.7s	remaining: 2m 7s
# 97:	learn: 0.3427251	total: 13.8s	remaining: 2m 6s
# 98:	learn: 0.3425821	total: 13.9s	remaining: 2m 6s
# 99:	learn: 0.3425198	total: 14s	remaining: 2m 5s
# 100:	learn: 0.3424322	total: 14s	remaining: 2m 4s
# 101:	learn: 0.3417640	total: 14.1s	remaining: 2m 4s
# 102:	learn: 0.3416314	total: 14.2s	remaining: 2m 3s
# 103:	learn: 0.3408286	total: 14.3s	remaining: 2m 3s
# 104:	learn: 0.3405534	total: 14.4s	remaining: 2m 2s
# 105:	learn: 0.3396240	total: 14.5s	remaining: 2m 2s
# 106:	learn: 0.3394779	total: 14.6s	remaining: 2m 1s
# 107:	learn: 0.3385206	total: 14.7s	remaining: 2m 1s
# 108:	learn: 0.3384491	total: 14.8s	remaining: 2m
# 109:	learn: 0.3380846	total: 14.8s	remaining: 2m
# 110:	learn: 0.3368152	total: 15s	remaining: 1m 59s
# 111:	learn: 0.3367361	total: 15.1s	remaining: 1m 59s
# 112:	learn: 0.3365560	total: 15.1s	remaining: 1m 58s
# 113:	learn: 0.3345728	total: 15.3s	remaining: 1m 58s
# 114:	learn: 0.3324584	total: 15.4s	remaining: 1m 58s
# 115:	learn: 0.3322691	total: 15.5s	remaining: 1m 57s
# 116:	learn: 0.3321876	total: 15.6s	remaining: 1m 57s
# 117:	learn: 0.3309541	total: 15.6s	remaining: 1m 56s
# 118:	learn: 0.3304433	total: 15.7s	remaining: 1m 56s
# 119:	learn: 0.3303440	total: 15.8s	remaining: 1m 56s
# 120:	learn: 0.3303158	total: 15.9s	remaining: 1m 55s
# 121:	learn: 0.3298542	total: 16s	remaining: 1m 55s
# 122:	learn: 0.3297399	total: 16.1s	remaining: 1m 54s
# 123:	learn: 0.3285051	total: 16.2s	remaining: 1m 54s
# 124:	learn: 0.3272669	total: 16.3s	remaining: 1m 54s
# 125:	learn: 0.3267064	total: 16.4s	remaining: 1m 53s
# 126:	learn: 0.3265873	total: 16.5s	remaining: 1m 53s
# 127:	learn: 0.3265468	total: 16.6s	remaining: 1m 52s
# 128:	learn: 0.3265054	total: 16.7s	remaining: 1m 52s
# 129:	learn: 0.3257485	total: 16.7s	remaining: 1m 52s
# 130:	learn: 0.3256453	total: 16.8s	remaining: 1m 51s
# 131:	learn: 0.3255920	total: 16.9s	remaining: 1m 51s
# 132:	learn: 0.3254737	total: 17s	remaining: 1m 50s
# 133:	learn: 0.3254333	total: 17.1s	remaining: 1m 50s
# 134:	learn: 0.3252335	total: 17.2s	remaining: 1m 50s
# 135:	learn: 0.3241503	total: 17.3s	remaining: 1m 49s
# 136:	learn: 0.3240746	total: 17.4s	remaining: 1m 49s
# 137:	learn: 0.3233300	total: 17.5s	remaining: 1m 49s
# 138:	learn: 0.3232731	total: 17.6s	remaining: 1m 48s
# 139:	learn: 0.3232032	total: 17.6s	remaining: 1m 48s
# 140:	learn: 0.3226341	total: 17.8s	remaining: 1m 48s
# 141:	learn: 0.3224713	total: 17.8s	remaining: 1m 47s
# 142:	learn: 0.3224389	total: 17.9s	remaining: 1m 47s
# 143:	learn: 0.3222929	total: 18s	remaining: 1m 47s
# 144:	learn: 0.3222624	total: 18.1s	remaining: 1m 46s
# 145:	learn: 0.3213478	total: 18.2s	remaining: 1m 46s
# 146:	learn: 0.3209572	total: 18.3s	remaining: 1m 46s
# 147:	learn: 0.3200738	total: 18.4s	remaining: 1m 45s
# 148:	learn: 0.3199324	total: 18.5s	remaining: 1m 45s
# 149:	learn: 0.3198653	total: 18.6s	remaining: 1m 45s
# 150:	learn: 0.3194126	total: 18.7s	remaining: 1m 45s
# 151:	learn: 0.3193480	total: 18.8s	remaining: 1m 44s
# 152:	learn: 0.3185387	total: 18.9s	remaining: 1m 44s
# 153:	learn: 0.3184628	total: 19s	remaining: 1m 44s
# 154:	learn: 0.3183668	total: 19.1s	remaining: 1m 43s
# 155:	learn: 0.3182115	total: 19.2s	remaining: 1m 43s
# 156:	learn: 0.3181253	total: 19.3s	remaining: 1m 43s
# 157:	learn: 0.3174531	total: 19.4s	remaining: 1m 43s
# 158:	learn: 0.3173828	total: 19.4s	remaining: 1m 42s
# 159:	learn: 0.3173411	total: 19.5s	remaining: 1m 42s
# 160:	learn: 0.3172596	total: 19.6s	remaining: 1m 42s
# 161:	learn: 0.3172288	total: 19.7s	remaining: 1m 41s
# 162:	learn: 0.3171706	total: 19.8s	remaining: 1m 41s
# 163:	learn: 0.3171285	total: 19.9s	remaining: 1m 41s
# 164:	learn: 0.3165701	total: 20s	remaining: 1m 41s
# 165:	learn: 0.3165062	total: 20.1s	remaining: 1m 40s
# 166:	learn: 0.3164469	total: 20.2s	remaining: 1m 40s
# 167:	learn: 0.3147236	total: 20.3s	remaining: 1m 40s
# 168:	learn: 0.3146393	total: 20.4s	remaining: 1m 40s
# 169:	learn: 0.3138561	total: 20.5s	remaining: 1m 39s
# 170:	learn: 0.3132597	total: 20.6s	remaining: 1m 39s
# 171:	learn: 0.3132004	total: 20.7s	remaining: 1m 39s
# 172:	learn: 0.3131030	total: 20.8s	remaining: 1m 39s
# 173:	learn: 0.3110612	total: 20.9s	remaining: 1m 39s
# 174:	learn: 0.3109732	total: 21s	remaining: 1m 38s
# 175:	learn: 0.3108779	total: 21s	remaining: 1m 38s
# 176:	learn: 0.3108247	total: 21.1s	remaining: 1m 38s
# 177:	learn: 0.3107417	total: 21.2s	remaining: 1m 38s
# 178:	learn: 0.3106802	total: 21.3s	remaining: 1m 37s
# 179:	learn: 0.3102353	total: 21.4s	remaining: 1m 37s
# 180:	learn: 0.3101679	total: 21.5s	remaining: 1m 37s
# 181:	learn: 0.3092749	total: 21.6s	remaining: 1m 37s
# 182:	learn: 0.3092110	total: 21.7s	remaining: 1m 36s
# 183:	learn: 0.3091186	total: 21.8s	remaining: 1m 36s
# 184:	learn: 0.3089947	total: 21.9s	remaining: 1m 36s
# 185:	learn: 0.3088632	total: 22s	remaining: 1m 36s
# 186:	learn: 0.3087979	total: 22s	remaining: 1m 35s
# 187:	learn: 0.3087556	total: 22.1s	remaining: 1m 35s
# 188:	learn: 0.3086941	total: 22.2s	remaining: 1m 35s
# 189:	learn: 0.3086031	total: 22.3s	remaining: 1m 35s
# 190:	learn: 0.3085442	total: 22.4s	remaining: 1m 34s
# 191:	learn: 0.3084887	total: 22.5s	remaining: 1m 34s
# 192:	learn: 0.3079050	total: 22.6s	remaining: 1m 34s
# 193:	learn: 0.3078527	total: 22.7s	remaining: 1m 34s
# 194:	learn: 0.3078140	total: 22.8s	remaining: 1m 33s
# 195:	learn: 0.3077358	total: 22.9s	remaining: 1m 33s
# 196:	learn: 0.3076472	total: 22.9s	remaining: 1m 33s
# 197:	learn: 0.3075957	total: 23s	remaining: 1m 33s
# 198:	learn: 0.3071873	total: 23.1s	remaining: 1m 33s
# 199:	learn: 0.3071046	total: 23.2s	remaining: 1m 32s
# 200:	learn: 0.3070615	total: 23.3s	remaining: 1m 32s
# 201:	learn: 0.3066934	total: 23.4s	remaining: 1m 32s
# 202:	learn: 0.3065345	total: 23.5s	remaining: 1m 32s
# 203:	learn: 0.3062313	total: 23.6s	remaining: 1m 32s
# 204:	learn: 0.3061777	total: 23.7s	remaining: 1m 31s
# 205:	learn: 0.3061005	total: 23.8s	remaining: 1m 31s
# 206:	learn: 0.3060462	total: 23.9s	remaining: 1m 31s
# 207:	learn: 0.3060121	total: 23.9s	remaining: 1m 31s
# 208:	learn: 0.3059642	total: 24s	remaining: 1m 30s
# 209:	learn: 0.3059011	total: 24.1s	remaining: 1m 30s
# 210:	learn: 0.3057208	total: 24.2s	remaining: 1m 30s
# 211:	learn: 0.3056289	total: 24.3s	remaining: 1m 30s
# 212:	learn: 0.3053552	total: 24.4s	remaining: 1m 30s
# 213:	learn: 0.3052772	total: 24.5s	remaining: 1m 29s
# 214:	learn: 0.3051586	total: 24.6s	remaining: 1m 29s
# 215:	learn: 0.3051223	total: 24.7s	remaining: 1m 29s
# 216:	learn: 0.3050628	total: 24.7s	remaining: 1m 29s
# 217:	learn: 0.3046758	total: 24.8s	remaining: 1m 29s
# 218:	learn: 0.3040635	total: 24.9s	remaining: 1m 28s
# 219:	learn: 0.3040037	total: 25s	remaining: 1m 28s
# 220:	learn: 0.3039567	total: 25.1s	remaining: 1m 28s
# 221:	learn: 0.3039171	total: 25.2s	remaining: 1m 28s
# 222:	learn: 0.3038196	total: 25.3s	remaining: 1m 28s
# 223:	learn: 0.3037643	total: 25.3s	remaining: 1m 27s
# 224:	learn: 0.3037197	total: 25.4s	remaining: 1m 27s
# 225:	learn: 0.3036436	total: 25.5s	remaining: 1m 27s
# 226:	learn: 0.3035630	total: 25.6s	remaining: 1m 27s
# 227:	learn: 0.3033597	total: 25.7s	remaining: 1m 27s
# 228:	learn: 0.3032887	total: 25.8s	remaining: 1m 26s
# 229:	learn: 0.3032470	total: 25.9s	remaining: 1m 26s
# 230:	learn: 0.3031693	total: 26s	remaining: 1m 26s
# 231:	learn: 0.3031318	total: 26.1s	remaining: 1m 26s
# 232:	learn: 0.3030258	total: 26.1s	remaining: 1m 26s
# 233:	learn: 0.3029629	total: 26.2s	remaining: 1m 25s
# 234:	learn: 0.3028575	total: 26.3s	remaining: 1m 25s
# 235:	learn: 0.3024344	total: 26.4s	remaining: 1m 25s
# 236:	learn: 0.3023974	total: 26.5s	remaining: 1m 25s
# 237:	learn: 0.3023117	total: 26.6s	remaining: 1m 25s
# 238:	learn: 0.3016129	total: 26.7s	remaining: 1m 25s
# 239:	learn: 0.3015692	total: 26.8s	remaining: 1m 24s
# 240:	learn: 0.3015152	total: 26.9s	remaining: 1m 24s
# 241:	learn: 0.3011505	total: 27s	remaining: 1m 24s
# 242:	learn: 0.3010891	total: 27.1s	remaining: 1m 24s
# 243:	learn: 0.3010554	total: 27.2s	remaining: 1m 24s
# 244:	learn: 0.3005462	total: 27.2s	remaining: 1m 23s
# 245:	learn: 0.3004678	total: 27.3s	remaining: 1m 23s
# 246:	learn: 0.2998560	total: 27.4s	remaining: 1m 23s
# 247:	learn: 0.2992559	total: 27.5s	remaining: 1m 23s
# 248:	learn: 0.2987576	total: 27.6s	remaining: 1m 23s
# 249:	learn: 0.2981053	total: 27.7s	remaining: 1m 23s
# 250:	learn: 0.2976508	total: 27.8s	remaining: 1m 22s
# 251:	learn: 0.2975650	total: 27.9s	remaining: 1m 22s
# 252:	learn: 0.2974758	total: 28s	remaining: 1m 22s
# 253:	learn: 0.2974377	total: 28.1s	remaining: 1m 22s
# 254:	learn: 0.2973389	total: 28.2s	remaining: 1m 22s
# 255:	learn: 0.2973008	total: 28.2s	remaining: 1m 22s
# 256:	learn: 0.2972394	total: 28.3s	remaining: 1m 21s
# 257:	learn: 0.2971499	total: 28.4s	remaining: 1m 21s
# 258:	learn: 0.2966662	total: 28.5s	remaining: 1m 21s
# 259:	learn: 0.2962532	total: 28.6s	remaining: 1m 21s
# 260:	learn: 0.2960082	total: 28.7s	remaining: 1m 21s
# 261:	learn: 0.2959604	total: 28.8s	remaining: 1m 21s
# 262:	learn: 0.2959001	total: 28.9s	remaining: 1m 20s
# 263:	learn: 0.2957060	total: 29s	remaining: 1m 20s
# 264:	learn: 0.2956525	total: 29.1s	remaining: 1m 20s
# 265:	learn: 0.2956006	total: 29.2s	remaining: 1m 20s
# 266:	learn: 0.2951455	total: 29.3s	remaining: 1m 20s
# 267:	learn: 0.2948267	total: 29.4s	remaining: 1m 20s
# 268:	learn: 0.2947694	total: 29.5s	remaining: 1m 20s
# 269:	learn: 0.2946996	total: 29.6s	remaining: 1m 19s
# 270:	learn: 0.2946390	total: 29.6s	remaining: 1m 19s
# 271:	learn: 0.2945897	total: 29.7s	remaining: 1m 19s
# 272:	learn: 0.2945394	total: 29.8s	remaining: 1m 19s
# 273:	learn: 0.2945030	total: 29.9s	remaining: 1m 19s
# 274:	learn: 0.2944443	total: 30s	remaining: 1m 19s
# 275:	learn: 0.2943959	total: 30.1s	remaining: 1m 18s
# 276:	learn: 0.2943306	total: 30.2s	remaining: 1m 18s
# 277:	learn: 0.2942629	total: 30.3s	remaining: 1m 18s
# 278:	learn: 0.2942224	total: 30.4s	remaining: 1m 18s
# 279:	learn: 0.2941591	total: 30.4s	remaining: 1m 18s
# 280:	learn: 0.2940657	total: 30.5s	remaining: 1m 18s
# 281:	learn: 0.2938529	total: 30.6s	remaining: 1m 17s
# 282:	learn: 0.2938102	total: 30.7s	remaining: 1m 17s
# 283:	learn: 0.2937509	total: 30.8s	remaining: 1m 17s
# 284:	learn: 0.2937019	total: 30.9s	remaining: 1m 17s
# 285:	learn: 0.2929390	total: 31s	remaining: 1m 17s
# 286:	learn: 0.2915467	total: 31.1s	remaining: 1m 17s
# 287:	learn: 0.2915116	total: 31.2s	remaining: 1m 17s
# 288:	learn: 0.2914701	total: 31.3s	remaining: 1m 16s
# 289:	learn: 0.2914266	total: 31.4s	remaining: 1m 16s
# 290:	learn: 0.2913489	total: 31.5s	remaining: 1m 16s
# 291:	learn: 0.2913005	total: 31.5s	remaining: 1m 16s
# 292:	learn: 0.2912564	total: 31.6s	remaining: 1m 16s
# 293:	learn: 0.2912160	total: 31.7s	remaining: 1m 16s
# 294:	learn: 0.2911791	total: 31.8s	remaining: 1m 16s
# 295:	learn: 0.2911250	total: 31.9s	remaining: 1m 15s
# 296:	learn: 0.2907648	total: 32s	remaining: 1m 15s
# 297:	learn: 0.2906940	total: 32.1s	remaining: 1m 15s
# 298:	learn: 0.2906665	total: 32.2s	remaining: 1m 15s
# 299:	learn: 0.2906297	total: 32.3s	remaining: 1m 15s
# 300:	learn: 0.2903084	total: 32.4s	remaining: 1m 15s
# 301:	learn: 0.2902504	total: 32.5s	remaining: 1m 15s
# 302:	learn: 0.2898503	total: 32.6s	remaining: 1m 14s
# 303:	learn: 0.2898200	total: 32.7s	remaining: 1m 14s
# 304:	learn: 0.2893470	total: 32.8s	remaining: 1m 14s
# 305:	learn: 0.2893010	total: 32.9s	remaining: 1m 14s
# 306:	learn: 0.2888147	total: 33s	remaining: 1m 14s
# 307:	learn: 0.2887739	total: 33.1s	remaining: 1m 14s
# 308:	learn: 0.2887375	total: 33.2s	remaining: 1m 14s
# 309:	learn: 0.2881372	total: 33.3s	remaining: 1m 14s
# 310:	learn: 0.2881064	total: 33.3s	remaining: 1m 13s
# 311:	learn: 0.2880738	total: 33.4s	remaining: 1m 13s
# 312:	learn: 0.2880481	total: 33.5s	remaining: 1m 13s
# 313:	learn: 0.2879949	total: 33.6s	remaining: 1m 13s
# 314:	learn: 0.2879550	total: 33.7s	remaining: 1m 13s
# 315:	learn: 0.2879070	total: 33.8s	remaining: 1m 13s
# 316:	learn: 0.2878725	total: 33.9s	remaining: 1m 13s
# 317:	learn: 0.2878298	total: 34s	remaining: 1m 12s
# 318:	learn: 0.2877895	total: 34.1s	remaining: 1m 12s
# 319:	learn: 0.2870999	total: 34.2s	remaining: 1m 12s
# 320:	learn: 0.2870570	total: 34.2s	remaining: 1m 12s
# 321:	learn: 0.2870136	total: 34.3s	remaining: 1m 12s
# 322:	learn: 0.2866497	total: 34.4s	remaining: 1m 12s
# 323:	learn: 0.2866023	total: 34.5s	remaining: 1m 12s
# 324:	learn: 0.2865751	total: 34.6s	remaining: 1m 11s
# 325:	learn: 0.2865280	total: 34.7s	remaining: 1m 11s
# 326:	learn: 0.2864978	total: 34.8s	remaining: 1m 11s
# 327:	learn: 0.2864553	total: 34.9s	remaining: 1m 11s
# 328:	learn: 0.2864154	total: 35s	remaining: 1m 11s
# 329:	learn: 0.2863757	total: 35s	remaining: 1m 11s
# 330:	learn: 0.2862659	total: 35.1s	remaining: 1m 11s
# 331:	learn: 0.2862390	total: 35.2s	remaining: 1m 10s
# 332:	learn: 0.2861704	total: 35.3s	remaining: 1m 10s
# 333:	learn: 0.2853623	total: 35.4s	remaining: 1m 10s
# 334:	learn: 0.2853055	total: 35.5s	remaining: 1m 10s
# 335:	learn: 0.2852531	total: 35.6s	remaining: 1m 10s
# 336:	learn: 0.2847864	total: 35.7s	remaining: 1m 10s
# 337:	learn: 0.2847511	total: 35.8s	remaining: 1m 10s
# 338:	learn: 0.2846421	total: 35.9s	remaining: 1m 10s
# 339:	learn: 0.2846071	total: 36s	remaining: 1m 9s
# 340:	learn: 0.2845724	total: 36.1s	remaining: 1m 9s
# 341:	learn: 0.2840665	total: 36.2s	remaining: 1m 9s
# 342:	learn: 0.2833097	total: 36.3s	remaining: 1m 9s
# 343:	learn: 0.2832743	total: 36.4s	remaining: 1m 9s
# 344:	learn: 0.2832382	total: 36.5s	remaining: 1m 9s
# 345:	learn: 0.2831842	total: 36.6s	remaining: 1m 9s
# 346:	learn: 0.2831296	total: 36.7s	remaining: 1m 9s
# 347:	learn: 0.2830484	total: 36.8s	remaining: 1m 8s
# 348:	learn: 0.2829361	total: 36.9s	remaining: 1m 8s
# 349:	learn: 0.2828936	total: 36.9s	remaining: 1m 8s
# 350:	learn: 0.2828402	total: 37s	remaining: 1m 8s
# 351:	learn: 0.2827873	total: 37.1s	remaining: 1m 8s
# 352:	learn: 0.2827426	total: 37.2s	remaining: 1m 8s
# 353:	learn: 0.2825593	total: 37.3s	remaining: 1m 8s
# 354:	learn: 0.2825203	total: 37.4s	remaining: 1m 7s
# 355:	learn: 0.2824658	total: 37.5s	remaining: 1m 7s
# 356:	learn: 0.2824407	total: 37.6s	remaining: 1m 7s
# 357:	learn: 0.2821039	total: 37.7s	remaining: 1m 7s
# 358:	learn: 0.2820598	total: 37.8s	remaining: 1m 7s
# 359:	learn: 0.2820250	total: 37.9s	remaining: 1m 7s
# 360:	learn: 0.2819863	total: 38s	remaining: 1m 7s
# 361:	learn: 0.2819431	total: 38.1s	remaining: 1m 7s
# 362:	learn: 0.2814102	total: 38.2s	remaining: 1m 6s
# 363:	learn: 0.2813625	total: 38.3s	remaining: 1m 6s
# 364:	learn: 0.2812948	total: 38.3s	remaining: 1m 6s
# 365:	learn: 0.2812251	total: 38.4s	remaining: 1m 6s
# 366:	learn: 0.2811812	total: 38.5s	remaining: 1m 6s
# 367:	learn: 0.2811177	total: 38.6s	remaining: 1m 6s
# 368:	learn: 0.2803414	total: 38.7s	remaining: 1m 6s
# 369:	learn: 0.2802935	total: 38.8s	remaining: 1m 6s
# 370:	learn: 0.2802406	total: 38.9s	remaining: 1m 5s
# 371:	learn: 0.2801935	total: 39s	remaining: 1m 5s
# 372:	learn: 0.2801424	total: 39.1s	remaining: 1m 5s
# 373:	learn: 0.2801110	total: 39.2s	remaining: 1m 5s
# 374:	learn: 0.2800180	total: 39.3s	remaining: 1m 5s
# 375:	learn: 0.2799744	total: 39.4s	remaining: 1m 5s
# 376:	learn: 0.2799213	total: 39.4s	remaining: 1m 5s
# 377:	learn: 0.2796025	total: 39.5s	remaining: 1m 5s
# 378:	learn: 0.2795732	total: 39.6s	remaining: 1m 4s
# 379:	learn: 0.2795229	total: 39.7s	remaining: 1m 4s
# 380:	learn: 0.2794731	total: 39.8s	remaining: 1m 4s
# 381:	learn: 0.2794257	total: 39.9s	remaining: 1m 4s
# 382:	learn: 0.2793530	total: 40s	remaining: 1m 4s
# 383:	learn: 0.2793196	total: 40.1s	remaining: 1m 4s
# 384:	learn: 0.2792820	total: 40.2s	remaining: 1m 4s
# 385:	learn: 0.2792217	total: 40.3s	remaining: 1m 4s
# 386:	learn: 0.2791635	total: 40.4s	remaining: 1m 3s
# 387:	learn: 0.2791245	total: 40.5s	remaining: 1m 3s
# 388:	learn: 0.2790662	total: 40.5s	remaining: 1m 3s
# 389:	learn: 0.2786107	total: 40.7s	remaining: 1m 3s
# 390:	learn: 0.2785752	total: 40.7s	remaining: 1m 3s
# 391:	learn: 0.2785366	total: 40.8s	remaining: 1m 3s
# 392:	learn: 0.2784963	total: 40.9s	remaining: 1m 3s
# 393:	learn: 0.2784302	total: 41s	remaining: 1m 3s
# 394:	learn: 0.2783894	total: 41.1s	remaining: 1m 2s
# 395:	learn: 0.2783429	total: 41.2s	remaining: 1m 2s
# 396:	learn: 0.2782673	total: 41.3s	remaining: 1m 2s
# 397:	learn: 0.2782292	total: 41.4s	remaining: 1m 2s
# 398:	learn: 0.2777985	total: 41.5s	remaining: 1m 2s
# 399:	learn: 0.2775152	total: 41.6s	remaining: 1m 2s
# 400:	learn: 0.2774601	total: 41.7s	remaining: 1m 2s
# 401:	learn: 0.2773924	total: 41.8s	remaining: 1m 2s
# 402:	learn: 0.2771375	total: 41.9s	remaining: 1m 2s
# 403:	learn: 0.2771100	total: 42s	remaining: 1m 1s
# 404:	learn: 0.2770851	total: 42s	remaining: 1m 1s
# 405:	learn: 0.2770412	total: 42.1s	remaining: 1m 1s
# 406:	learn: 0.2769759	total: 42.2s	remaining: 1m 1s
# 407:	learn: 0.2769350	total: 42.3s	remaining: 1m 1s
# 408:	learn: 0.2768794	total: 42.4s	remaining: 1m 1s
# 409:	learn: 0.2768066	total: 42.5s	remaining: 1m 1s
# 410:	learn: 0.2767488	total: 42.6s	remaining: 1m 1s
# 411:	learn: 0.2766994	total: 42.7s	remaining: 1m
# 412:	learn: 0.2763175	total: 42.8s	remaining: 1m
# 413:	learn: 0.2761903	total: 42.8s	remaining: 1m
# 414:	learn: 0.2761562	total: 42.9s	remaining: 1m
# 415:	learn: 0.2761307	total: 43s	remaining: 1m
# 416:	learn: 0.2760686	total: 43.1s	remaining: 1m
# 417:	learn: 0.2760362	total: 43.2s	remaining: 1m
# 418:	learn: 0.2759929	total: 43.3s	remaining: 1m
# 419:	learn: 0.2759355	total: 43.4s	remaining: 59.9s
# 420:	learn: 0.2758866	total: 43.5s	remaining: 59.8s
# 421:	learn: 0.2758422	total: 43.6s	remaining: 59.7s
# 422:	learn: 0.2758052	total: 43.7s	remaining: 59.5s
# 423:	learn: 0.2757613	total: 43.7s	remaining: 59.4s
# 424:	learn: 0.2757023	total: 43.8s	remaining: 59.3s
# 425:	learn: 0.2756469	total: 43.9s	remaining: 59.2s
# 426:	learn: 0.2756146	total: 44s	remaining: 59.1s
# 427:	learn: 0.2755757	total: 44.1s	remaining: 58.9s
# 428:	learn: 0.2755114	total: 44.2s	remaining: 58.8s
# 429:	learn: 0.2754639	total: 44.3s	remaining: 58.7s
# 430:	learn: 0.2750031	total: 44.4s	remaining: 58.6s
# 431:	learn: 0.2749687	total: 44.5s	remaining: 58.5s
# 432:	learn: 0.2749408	total: 44.6s	remaining: 58.3s
# 433:	learn: 0.2749041	total: 44.6s	remaining: 58.2s
# 434:	learn: 0.2741793	total: 44.7s	remaining: 58.1s
# 435:	learn: 0.2741270	total: 44.8s	remaining: 58s
# 436:	learn: 0.2740887	total: 44.9s	remaining: 57.9s
# 437:	learn: 0.2740231	total: 45s	remaining: 57.8s
# 438:	learn: 0.2739777	total: 45.1s	remaining: 57.6s
# 439:	learn: 0.2739455	total: 45.2s	remaining: 57.5s
# 440:	learn: 0.2739050	total: 45.3s	remaining: 57.4s
# 441:	learn: 0.2733316	total: 45.4s	remaining: 57.3s
# 442:	learn: 0.2732808	total: 45.5s	remaining: 57.2s
# 443:	learn: 0.2729363	total: 45.6s	remaining: 57.1s
# 444:	learn: 0.2728870	total: 45.7s	remaining: 56.9s
# 445:	learn: 0.2728387	total: 45.7s	remaining: 56.8s
# 446:	learn: 0.2727895	total: 45.8s	remaining: 56.7s
# 447:	learn: 0.2727362	total: 45.9s	remaining: 56.6s
# 448:	learn: 0.2727129	total: 46s	remaining: 56.5s
# 449:	learn: 0.2726732	total: 46.1s	remaining: 56.4s
# 450:	learn: 0.2726372	total: 46.2s	remaining: 56.2s
# 451:	learn: 0.2725978	total: 46.3s	remaining: 56.1s
# 452:	learn: 0.2725618	total: 46.4s	remaining: 56s
# 453:	learn: 0.2725055	total: 46.5s	remaining: 55.9s
# 454:	learn: 0.2724767	total: 46.6s	remaining: 55.8s
# 455:	learn: 0.2724501	total: 46.6s	remaining: 55.6s
# 456:	learn: 0.2715738	total: 46.7s	remaining: 55.5s
# 457:	learn: 0.2715356	total: 46.8s	remaining: 55.4s
# 458:	learn: 0.2714748	total: 46.9s	remaining: 55.3s
# 459:	learn: 0.2714226	total: 47s	remaining: 55.2s
# 460:	learn: 0.2712798	total: 47.1s	remaining: 55.1s
# 461:	learn: 0.2712448	total: 47.2s	remaining: 55s
# 462:	learn: 0.2711899	total: 47.3s	remaining: 54.9s
# 463:	learn: 0.2711418	total: 47.4s	remaining: 54.7s
# 464:	learn: 0.2710966	total: 47.5s	remaining: 54.6s
# 465:	learn: 0.2710527	total: 47.6s	remaining: 54.5s
# 466:	learn: 0.2709898	total: 47.7s	remaining: 54.4s
# 467:	learn: 0.2709569	total: 47.7s	remaining: 54.3s
# 468:	learn: 0.2709276	total: 47.8s	remaining: 54.2s
# 469:	learn: 0.2708920	total: 47.9s	remaining: 54s
# 470:	learn: 0.2708579	total: 48s	remaining: 53.9s
# 471:	learn: 0.2708266	total: 48.1s	remaining: 53.8s
# 472:	learn: 0.2707768	total: 48.2s	remaining: 53.7s
# 473:	learn: 0.2707326	total: 48.3s	remaining: 53.6s
# 474:	learn: 0.2707084	total: 48.4s	remaining: 53.5s
# 475:	learn: 0.2706616	total: 48.5s	remaining: 53.4s
# 476:	learn: 0.2705835	total: 48.6s	remaining: 53.2s
# 477:	learn: 0.2705522	total: 48.6s	remaining: 53.1s
# 478:	learn: 0.2705173	total: 48.7s	remaining: 53s
# 479:	learn: 0.2704898	total: 48.8s	remaining: 52.9s
# 480:	learn: 0.2704316	total: 48.9s	remaining: 52.8s
# 481:	learn: 0.2703579	total: 49s	remaining: 52.7s
# 482:	learn: 0.2703097	total: 49.1s	remaining: 52.6s
# 483:	learn: 0.2702149	total: 49.2s	remaining: 52.4s
# 484:	learn: 0.2701717	total: 49.3s	remaining: 52.3s
# 485:	learn: 0.2693849	total: 49.4s	remaining: 52.3s
# 486:	learn: 0.2693410	total: 49.5s	remaining: 52.1s
# 487:	learn: 0.2692578	total: 49.6s	remaining: 52s
# 488:	learn: 0.2685092	total: 49.7s	remaining: 52s
# 489:	learn: 0.2684626	total: 49.8s	remaining: 51.8s
# 490:	learn: 0.2684175	total: 49.9s	remaining: 51.7s
# 491:	learn: 0.2683551	total: 50s	remaining: 51.6s
# 492:	learn: 0.2683245	total: 50.1s	remaining: 51.5s
# 493:	learn: 0.2682934	total: 50.2s	remaining: 51.4s
# 494:	learn: 0.2682411	total: 50.3s	remaining: 51.3s
# 495:	learn: 0.2682168	total: 50.4s	remaining: 51.2s
# 496:	learn: 0.2681947	total: 50.5s	remaining: 51.1s
# 497:	learn: 0.2681461	total: 50.5s	remaining: 51s
# 498:	learn: 0.2681165	total: 50.6s	remaining: 50.8s
# 499:	learn: 0.2680944	total: 50.7s	remaining: 50.7s
# 500:	learn: 0.2680560	total: 50.8s	remaining: 50.6s
# 501:	learn: 0.2680052	total: 50.9s	remaining: 50.5s
# 502:	learn: 0.2674468	total: 51s	remaining: 50.4s
# 503:	learn: 0.2673318	total: 51.1s	remaining: 50.3s
# 504:	learn: 0.2672960	total: 51.2s	remaining: 50.2s
# 505:	learn: 0.2672644	total: 51.3s	remaining: 50s
# 506:	learn: 0.2672327	total: 51.4s	remaining: 49.9s
# 507:	learn: 0.2672058	total: 51.4s	remaining: 49.8s
# 508:	learn: 0.2671539	total: 51.5s	remaining: 49.7s
# 509:	learn: 0.2671111	total: 51.6s	remaining: 49.6s
# 510:	learn: 0.2670127	total: 51.7s	remaining: 49.5s
# 511:	learn: 0.2669760	total: 51.8s	remaining: 49.4s
# 512:	learn: 0.2669150	total: 51.9s	remaining: 49.3s
# 513:	learn: 0.2668542	total: 52s	remaining: 49.2s
# 514:	learn: 0.2668042	total: 52.1s	remaining: 49.1s
# 515:	learn: 0.2667684	total: 52.2s	remaining: 48.9s
# 516:	learn: 0.2667319	total: 52.3s	remaining: 48.8s
# 517:	learn: 0.2666975	total: 52.4s	remaining: 48.7s
# 518:	learn: 0.2666705	total: 52.5s	remaining: 48.6s
# 519:	learn: 0.2665928	total: 52.5s	remaining: 48.5s
# 520:	learn: 0.2665647	total: 52.6s	remaining: 48.4s
# 521:	learn: 0.2665151	total: 52.7s	remaining: 48.3s
# 522:	learn: 0.2664850	total: 52.8s	remaining: 48.2s
# 523:	learn: 0.2664144	total: 52.9s	remaining: 48.1s
# 524:	learn: 0.2663508	total: 53s	remaining: 47.9s
# 525:	learn: 0.2663114	total: 53.1s	remaining: 47.8s
# 526:	learn: 0.2662626	total: 53.2s	remaining: 47.7s
# 527:	learn: 0.2662285	total: 53.3s	remaining: 47.6s
# 528:	learn: 0.2661831	total: 53.4s	remaining: 47.5s
# 529:	learn: 0.2661459	total: 53.4s	remaining: 47.4s
# 530:	learn: 0.2661109	total: 53.5s	remaining: 47.3s
# 531:	learn: 0.2660798	total: 53.6s	remaining: 47.2s
# 532:	learn: 0.2660157	total: 53.7s	remaining: 47.1s
# 533:	learn: 0.2659617	total: 53.8s	remaining: 47s
# 534:	learn: 0.2659390	total: 53.9s	remaining: 46.8s
# 535:	learn: 0.2659079	total: 54s	remaining: 46.7s
# 536:	learn: 0.2658777	total: 54.1s	remaining: 46.6s
# 537:	learn: 0.2658511	total: 54.2s	remaining: 46.5s
# 538:	learn: 0.2657805	total: 54.3s	remaining: 46.4s
# 539:	learn: 0.2655234	total: 54.4s	remaining: 46.3s
# 540:	learn: 0.2654892	total: 54.4s	remaining: 46.2s
# 541:	learn: 0.2654301	total: 54.5s	remaining: 46.1s
# 542:	learn: 0.2653898	total: 54.6s	remaining: 46s
# 543:	learn: 0.2653449	total: 54.7s	remaining: 45.9s
# 544:	learn: 0.2653130	total: 54.8s	remaining: 45.8s
# 545:	learn: 0.2652823	total: 54.9s	remaining: 45.7s
# 546:	learn: 0.2652567	total: 55s	remaining: 45.5s
# 547:	learn: 0.2652305	total: 55.1s	remaining: 45.4s
# 548:	learn: 0.2651872	total: 55.2s	remaining: 45.3s
# 549:	learn: 0.2648665	total: 55.3s	remaining: 45.2s
# 550:	learn: 0.2648260	total: 55.4s	remaining: 45.1s
# 551:	learn: 0.2646349	total: 55.5s	remaining: 45s
# 552:	learn: 0.2646007	total: 55.6s	remaining: 44.9s
# 553:	learn: 0.2645750	total: 55.7s	remaining: 44.8s
# 554:	learn: 0.2643666	total: 55.8s	remaining: 44.7s
# 555:	learn: 0.2643177	total: 55.9s	remaining: 44.6s
# 556:	learn: 0.2642779	total: 55.9s	remaining: 44.5s
# 557:	learn: 0.2642117	total: 56s	remaining: 44.4s
# 558:	learn: 0.2638789	total: 56.1s	remaining: 44.3s
# 559:	learn: 0.2638391	total: 56.2s	remaining: 44.2s
# 560:	learn: 0.2638125	total: 56.3s	remaining: 44.1s
# 561:	learn: 0.2637837	total: 56.4s	remaining: 44s
# 562:	learn: 0.2637430	total: 56.5s	remaining: 43.9s
# 563:	learn: 0.2637207	total: 56.6s	remaining: 43.7s
# 564:	learn: 0.2636317	total: 56.7s	remaining: 43.6s
# 565:	learn: 0.2635569	total: 56.8s	remaining: 43.5s
# 566:	learn: 0.2635249	total: 56.9s	remaining: 43.4s
# 567:	learn: 0.2634864	total: 57s	remaining: 43.3s
# 568:	learn: 0.2632596	total: 57.1s	remaining: 43.2s
# 569:	learn: 0.2632322	total: 57.2s	remaining: 43.1s
# 570:	learn: 0.2631986	total: 57.2s	remaining: 43s
# 571:	learn: 0.2631684	total: 57.3s	remaining: 42.9s
# 572:	learn: 0.2631139	total: 57.4s	remaining: 42.8s
# 573:	learn: 0.2630779	total: 57.5s	remaining: 42.7s
# 574:	learn: 0.2629956	total: 57.6s	remaining: 42.6s
# 575:	learn: 0.2625929	total: 57.7s	remaining: 42.5s
# 576:	learn: 0.2625631	total: 57.8s	remaining: 42.4s
# 577:	learn: 0.2625191	total: 57.9s	remaining: 42.2s
# 578:	learn: 0.2624961	total: 58s	remaining: 42.1s
# 579:	learn: 0.2624455	total: 58s	remaining: 42s
# 580:	learn: 0.2624090	total: 58.1s	remaining: 41.9s
# 581:	learn: 0.2623842	total: 58.2s	remaining: 41.8s
# 582:	learn: 0.2619493	total: 58.3s	remaining: 41.7s
# 583:	learn: 0.2619087	total: 58.4s	remaining: 41.6s
# 584:	learn: 0.2618845	total: 58.5s	remaining: 41.5s
# 585:	learn: 0.2618523	total: 58.6s	remaining: 41.4s
# 586:	learn: 0.2618049	total: 58.7s	remaining: 41.3s
# 587:	learn: 0.2609181	total: 58.8s	remaining: 41.2s
# 588:	learn: 0.2608926	total: 58.9s	remaining: 41.1s
# 589:	learn: 0.2608601	total: 59s	remaining: 41s
# 590:	learn: 0.2608143	total: 59.1s	remaining: 40.9s
# 591:	learn: 0.2607730	total: 59.1s	remaining: 40.8s
# 592:	learn: 0.2607297	total: 59.2s	remaining: 40.7s
# 593:	learn: 0.2606982	total: 59.3s	remaining: 40.6s
# 594:	learn: 0.2605914	total: 59.4s	remaining: 40.4s
# 595:	learn: 0.2605461	total: 59.5s	remaining: 40.3s
# 596:	learn: 0.2605119	total: 59.6s	remaining: 40.2s
# 597:	learn: 0.2604798	total: 59.7s	remaining: 40.1s
# 598:	learn: 0.2604271	total: 59.8s	remaining: 40s
# 599:	learn: 0.2603997	total: 59.9s	remaining: 39.9s
# 600:	learn: 0.2603670	total: 60s	remaining: 39.8s
# 601:	learn: 0.2603364	total: 1m	remaining: 39.7s
# 602:	learn: 0.2603026	total: 1m	remaining: 39.6s
# 603:	learn: 0.2602618	total: 1m	remaining: 39.5s
# 604:	learn: 0.2602395	total: 1m	remaining: 39.4s
# 605:	learn: 0.2601741	total: 1m	remaining: 39.3s
# 606:	learn: 0.2601429	total: 1m	remaining: 39.2s
# 607:	learn: 0.2601009	total: 1m	remaining: 39.1s
# 608:	learn: 0.2600530	total: 1m	remaining: 39s
# 609:	learn: 0.2600103	total: 1m	remaining: 38.9s
# 610:	learn: 0.2599781	total: 1m	remaining: 38.8s
# 611:	learn: 0.2598298	total: 1m	remaining: 38.7s
# 612:	learn: 0.2597907	total: 1m 1s	remaining: 38.5s
# 613:	learn: 0.2597495	total: 1m 1s	remaining: 38.4s
# 614:	learn: 0.2597157	total: 1m 1s	remaining: 38.3s
# 615:	learn: 0.2592595	total: 1m 1s	remaining: 38.2s
# 616:	learn: 0.2590009	total: 1m 1s	remaining: 38.2s
# 617:	learn: 0.2589683	total: 1m 1s	remaining: 38s
# 618:	learn: 0.2586772	total: 1m 1s	remaining: 37.9s
# 619:	learn: 0.2586220	total: 1m 1s	remaining: 37.8s
# 620:	learn: 0.2585730	total: 1m 1s	remaining: 37.7s
# 621:	learn: 0.2585166	total: 1m 1s	remaining: 37.6s
# 622:	learn: 0.2584852	total: 1m 2s	remaining: 37.5s
# 623:	learn: 0.2584528	total: 1m 2s	remaining: 37.4s
# 624:	learn: 0.2578719	total: 1m 2s	remaining: 37.3s
# 625:	learn: 0.2578447	total: 1m 2s	remaining: 37.2s
# 626:	learn: 0.2573524	total: 1m 2s	remaining: 37.1s
# 627:	learn: 0.2573265	total: 1m 2s	remaining: 37s
# 628:	learn: 0.2573045	total: 1m 2s	remaining: 36.9s
# 629:	learn: 0.2572470	total: 1m 2s	remaining: 36.8s
# 630:	learn: 0.2572145	total: 1m 2s	remaining: 36.7s
# 631:	learn: 0.2571842	total: 1m 2s	remaining: 36.6s
# 632:	learn: 0.2571454	total: 1m 2s	remaining: 36.5s
# 633:	learn: 0.2571154	total: 1m 3s	remaining: 36.4s
# 634:	learn: 0.2570608	total: 1m 3s	remaining: 36.3s
# 635:	learn: 0.2570213	total: 1m 3s	remaining: 36.2s
# 636:	learn: 0.2569977	total: 1m 3s	remaining: 36.1s
# 637:	learn: 0.2569626	total: 1m 3s	remaining: 36s
# 638:	learn: 0.2569269	total: 1m 3s	remaining: 35.9s
# 639:	learn: 0.2568887	total: 1m 3s	remaining: 35.8s
# 640:	learn: 0.2568552	total: 1m 3s	remaining: 35.7s
# 641:	learn: 0.2568268	total: 1m 3s	remaining: 35.6s
# 642:	learn: 0.2567860	total: 1m 3s	remaining: 35.5s
# 643:	learn: 0.2567582	total: 1m 3s	remaining: 35.4s
# 644:	learn: 0.2567047	total: 1m 4s	remaining: 35.3s
# 645:	learn: 0.2563799	total: 1m 4s	remaining: 35.2s
# 646:	learn: 0.2563193	total: 1m 4s	remaining: 35.1s
# 647:	learn: 0.2562358	total: 1m 4s	remaining: 35s
# 648:	learn: 0.2562128	total: 1m 4s	remaining: 34.9s
# 649:	learn: 0.2561785	total: 1m 4s	remaining: 34.7s
# 650:	learn: 0.2561485	total: 1m 4s	remaining: 34.6s
# 651:	learn: 0.2561254	total: 1m 4s	remaining: 34.5s
# 652:	learn: 0.2560900	total: 1m 4s	remaining: 34.4s
# 653:	learn: 0.2549973	total: 1m 4s	remaining: 34.4s
# 654:	learn: 0.2549634	total: 1m 5s	remaining: 34.3s
# 655:	learn: 0.2549347	total: 1m 5s	remaining: 34.1s
# 656:	learn: 0.2548987	total: 1m 5s	remaining: 34s
# 657:	learn: 0.2548662	total: 1m 5s	remaining: 33.9s
# 658:	learn: 0.2547718	total: 1m 5s	remaining: 33.8s
# 659:	learn: 0.2547457	total: 1m 5s	remaining: 33.7s
# 660:	learn: 0.2547228	total: 1m 5s	remaining: 33.6s
# 661:	learn: 0.2546856	total: 1m 5s	remaining: 33.5s
# 662:	learn: 0.2546475	total: 1m 5s	remaining: 33.4s
# 663:	learn: 0.2546117	total: 1m 5s	remaining: 33.3s
# 664:	learn: 0.2545757	total: 1m 5s	remaining: 33.2s
# 665:	learn: 0.2545516	total: 1m 6s	remaining: 33.1s
# 666:	learn: 0.2545284	total: 1m 6s	remaining: 33s
# 667:	learn: 0.2545028	total: 1m 6s	remaining: 32.9s
# 668:	learn: 0.2544709	total: 1m 6s	remaining: 32.8s
# 669:	learn: 0.2541228	total: 1m 6s	remaining: 32.7s
# 670:	learn: 0.2537985	total: 1m 6s	remaining: 32.6s
# 671:	learn: 0.2537705	total: 1m 6s	remaining: 32.5s
# 672:	learn: 0.2537404	total: 1m 6s	remaining: 32.4s
# 673:	learn: 0.2537069	total: 1m 6s	remaining: 32.3s
# 674:	learn: 0.2536733	total: 1m 6s	remaining: 32.2s
# 675:	learn: 0.2536319	total: 1m 6s	remaining: 32.1s
# 676:	learn: 0.2535886	total: 1m 7s	remaining: 32s
# 677:	learn: 0.2535550	total: 1m 7s	remaining: 31.9s
# 678:	learn: 0.2535116	total: 1m 7s	remaining: 31.8s
# 679:	learn: 0.2534843	total: 1m 7s	remaining: 31.7s
# 680:	learn: 0.2534433	total: 1m 7s	remaining: 31.6s
# 681:	learn: 0.2534078	total: 1m 7s	remaining: 31.5s
# 682:	learn: 0.2533807	total: 1m 7s	remaining: 31.4s
# 683:	learn: 0.2533395	total: 1m 7s	remaining: 31.3s
# 684:	learn: 0.2533083	total: 1m 7s	remaining: 31.2s
# 685:	learn: 0.2532772	total: 1m 7s	remaining: 31.1s
# 686:	learn: 0.2532502	total: 1m 7s	remaining: 31s
# 687:	learn: 0.2532226	total: 1m 8s	remaining: 30.9s
# 688:	learn: 0.2531962	total: 1m 8s	remaining: 30.8s
# 689:	learn: 0.2526081	total: 1m 8s	remaining: 30.7s
# 690:	learn: 0.2525804	total: 1m 8s	remaining: 30.6s
# 691:	learn: 0.2525280	total: 1m 8s	remaining: 30.5s
# 692:	learn: 0.2524931	total: 1m 8s	remaining: 30.4s
# 693:	learn: 0.2524598	total: 1m 8s	remaining: 30.3s
# 694:	learn: 0.2524224	total: 1m 8s	remaining: 30.1s
# 695:	learn: 0.2523849	total: 1m 8s	remaining: 30.1s
# 696:	learn: 0.2523561	total: 1m 8s	remaining: 29.9s
# 697:	learn: 0.2523184	total: 1m 8s	remaining: 29.8s
# 698:	learn: 0.2519276	total: 1m 9s	remaining: 29.8s
# 699:	learn: 0.2518848	total: 1m 9s	remaining: 29.7s
# 700:	learn: 0.2515087	total: 1m 9s	remaining: 29.6s
# 701:	learn: 0.2514805	total: 1m 9s	remaining: 29.5s
# 702:	learn: 0.2514570	total: 1m 9s	remaining: 29.3s
# 703:	learn: 0.2514218	total: 1m 9s	remaining: 29.2s
# 704:	learn: 0.2513965	total: 1m 9s	remaining: 29.1s
# 705:	learn: 0.2513624	total: 1m 9s	remaining: 29s
# 706:	learn: 0.2512747	total: 1m 9s	remaining: 28.9s
# 707:	learn: 0.2512480	total: 1m 9s	remaining: 28.8s
# 708:	learn: 0.2512186	total: 1m 10s	remaining: 28.7s
# 709:	learn: 0.2511908	total: 1m 10s	remaining: 28.6s
# 710:	learn: 0.2511498	total: 1m 10s	remaining: 28.5s
# 711:	learn: 0.2511190	total: 1m 10s	remaining: 28.4s
# 712:	learn: 0.2510699	total: 1m 10s	remaining: 28.3s
# 713:	learn: 0.2510419	total: 1m 10s	remaining: 28.2s
# 714:	learn: 0.2510068	total: 1m 10s	remaining: 28.1s
# 715:	learn: 0.2509727	total: 1m 10s	remaining: 28s
# 716:	learn: 0.2509326	total: 1m 10s	remaining: 27.9s
# 717:	learn: 0.2508699	total: 1m 10s	remaining: 27.8s
# 718:	learn: 0.2508289	total: 1m 10s	remaining: 27.7s
# 719:	learn: 0.2507936	total: 1m 11s	remaining: 27.6s
# 720:	learn: 0.2504809	total: 1m 11s	remaining: 27.5s
# 721:	learn: 0.2504574	total: 1m 11s	remaining: 27.4s
# 722:	learn: 0.2503209	total: 1m 11s	remaining: 27.3s
# 723:	learn: 0.2502984	total: 1m 11s	remaining: 27.2s
# 724:	learn: 0.2502630	total: 1m 11s	remaining: 27.1s
# 725:	learn: 0.2502286	total: 1m 11s	remaining: 27s
# 726:	learn: 0.2501979	total: 1m 11s	remaining: 26.9s
# 727:	learn: 0.2501352	total: 1m 11s	remaining: 26.8s
# 728:	learn: 0.2501035	total: 1m 11s	remaining: 26.7s
# 729:	learn: 0.2500687	total: 1m 11s	remaining: 26.6s
# 730:	learn: 0.2500279	total: 1m 12s	remaining: 26.5s
# 731:	learn: 0.2499798	total: 1m 12s	remaining: 26.4s
# 732:	learn: 0.2499190	total: 1m 12s	remaining: 26.3s
# 733:	learn: 0.2498910	total: 1m 12s	remaining: 26.2s
# 734:	learn: 0.2498562	total: 1m 12s	remaining: 26.1s
# 735:	learn: 0.2498078	total: 1m 12s	remaining: 26s
# 736:	learn: 0.2497736	total: 1m 12s	remaining: 25.9s
# 737:	learn: 0.2497488	total: 1m 12s	remaining: 25.8s
# 738:	learn: 0.2497192	total: 1m 12s	remaining: 25.7s
# 739:	learn: 0.2496967	total: 1m 12s	remaining: 25.6s
# 740:	learn: 0.2496354	total: 1m 12s	remaining: 25.5s
# 741:	learn: 0.2495918	total: 1m 13s	remaining: 25.4s
# 742:	learn: 0.2494460	total: 1m 13s	remaining: 25.3s
# 743:	learn: 0.2494146	total: 1m 13s	remaining: 25.2s
# 744:	learn: 0.2490629	total: 1m 13s	remaining: 25.1s
# 745:	learn: 0.2490316	total: 1m 13s	remaining: 25s
# 746:	learn: 0.2490014	total: 1m 13s	remaining: 24.9s
# 747:	learn: 0.2489780	total: 1m 13s	remaining: 24.8s
# 748:	learn: 0.2489538	total: 1m 13s	remaining: 24.7s
# 749:	learn: 0.2489306	total: 1m 13s	remaining: 24.6s
# 750:	learn: 0.2489012	total: 1m 13s	remaining: 24.5s
# 751:	learn: 0.2488702	total: 1m 14s	remaining: 24.4s
# 752:	learn: 0.2488416	total: 1m 14s	remaining: 24.3s
# 753:	learn: 0.2488050	total: 1m 14s	remaining: 24.2s
# 754:	learn: 0.2487596	total: 1m 14s	remaining: 24.1s
# 755:	learn: 0.2487063	total: 1m 14s	remaining: 24s
# 756:	learn: 0.2486807	total: 1m 14s	remaining: 23.9s
# 757:	learn: 0.2486501	total: 1m 14s	remaining: 23.8s
# 758:	learn: 0.2486069	total: 1m 14s	remaining: 23.7s
# 759:	learn: 0.2485688	total: 1m 14s	remaining: 23.6s
# 760:	learn: 0.2485326	total: 1m 14s	remaining: 23.5s
# 761:	learn: 0.2484896	total: 1m 14s	remaining: 23.4s
# 762:	learn: 0.2484597	total: 1m 15s	remaining: 23.3s
# 763:	learn: 0.2483837	total: 1m 15s	remaining: 23.2s
# 764:	learn: 0.2483498	total: 1m 15s	remaining: 23.1s
# 765:	learn: 0.2483213	total: 1m 15s	remaining: 23s
# 766:	learn: 0.2482802	total: 1m 15s	remaining: 22.9s
# 767:	learn: 0.2482498	total: 1m 15s	remaining: 22.8s
# 768:	learn: 0.2482080	total: 1m 15s	remaining: 22.7s
# 769:	learn: 0.2481495	total: 1m 15s	remaining: 22.6s
# 770:	learn: 0.2481258	total: 1m 15s	remaining: 22.5s
# 771:	learn: 0.2480917	total: 1m 15s	remaining: 22.4s
# 772:	learn: 0.2480634	total: 1m 15s	remaining: 22.3s
# 773:	learn: 0.2480055	total: 1m 16s	remaining: 22.2s
# 774:	learn: 0.2479661	total: 1m 16s	remaining: 22.1s
# 775:	learn: 0.2479425	total: 1m 16s	remaining: 22s
# 776:	learn: 0.2479115	total: 1m 16s	remaining: 21.9s
# 777:	learn: 0.2478813	total: 1m 16s	remaining: 21.8s
# 778:	learn: 0.2478342	total: 1m 16s	remaining: 21.7s
# 779:	learn: 0.2474849	total: 1m 16s	remaining: 21.6s
# 780:	learn: 0.2474360	total: 1m 16s	remaining: 21.5s
# 781:	learn: 0.2473933	total: 1m 16s	remaining: 21.4s
# 782:	learn: 0.2473623	total: 1m 16s	remaining: 21.3s
# 783:	learn: 0.2473247	total: 1m 16s	remaining: 21.2s
# 784:	learn: 0.2473015	total: 1m 17s	remaining: 21.1s
# 785:	learn: 0.2469702	total: 1m 17s	remaining: 21s
# 786:	learn: 0.2469439	total: 1m 17s	remaining: 20.9s
# 787:	learn: 0.2469196	total: 1m 17s	remaining: 20.8s
# 788:	learn: 0.2468871	total: 1m 17s	remaining: 20.7s
# 789:	learn: 0.2465835	total: 1m 17s	remaining: 20.6s
# 790:	learn: 0.2465432	total: 1m 17s	remaining: 20.5s
# 791:	learn: 0.2465186	total: 1m 17s	remaining: 20.4s
# 792:	learn: 0.2464915	total: 1m 17s	remaining: 20.3s
# 793:	learn: 0.2464612	total: 1m 17s	remaining: 20.2s
# 794:	learn: 0.2462238	total: 1m 18s	remaining: 20.1s
# 795:	learn: 0.2461973	total: 1m 18s	remaining: 20s
# 796:	learn: 0.2458603	total: 1m 18s	remaining: 19.9s
# 797:	learn: 0.2458223	total: 1m 18s	remaining: 19.8s
# 798:	learn: 0.2457228	total: 1m 18s	remaining: 19.7s
# 799:	learn: 0.2456465	total: 1m 18s	remaining: 19.6s
# 800:	learn: 0.2456199	total: 1m 18s	remaining: 19.5s
# 801:	learn: 0.2453509	total: 1m 18s	remaining: 19.4s
# 802:	learn: 0.2453250	total: 1m 18s	remaining: 19.3s
# 803:	learn: 0.2452831	total: 1m 18s	remaining: 19.2s
# 804:	learn: 0.2446328	total: 1m 18s	remaining: 19.1s
# 805:	learn: 0.2446043	total: 1m 19s	remaining: 19s
# 806:	learn: 0.2445686	total: 1m 19s	remaining: 18.9s
# 807:	learn: 0.2445283	total: 1m 19s	remaining: 18.8s
# 808:	learn: 0.2445064	total: 1m 19s	remaining: 18.7s
# 809:	learn: 0.2444759	total: 1m 19s	remaining: 18.6s
# 810:	learn: 0.2444538	total: 1m 19s	remaining: 18.5s
# 811:	learn: 0.2444298	total: 1m 19s	remaining: 18.4s
# 812:	learn: 0.2443810	total: 1m 19s	remaining: 18.3s
# 813:	learn: 0.2443485	total: 1m 19s	remaining: 18.2s
# 814:	learn: 0.2443145	total: 1m 19s	remaining: 18.1s
# 815:	learn: 0.2442863	total: 1m 20s	remaining: 18s
# 816:	learn: 0.2442131	total: 1m 20s	remaining: 17.9s
# 817:	learn: 0.2441827	total: 1m 20s	remaining: 17.8s
# 818:	learn: 0.2440987	total: 1m 20s	remaining: 17.7s
# 819:	learn: 0.2440638	total: 1m 20s	remaining: 17.6s
# 820:	learn: 0.2440404	total: 1m 20s	remaining: 17.5s
# 821:	learn: 0.2439900	total: 1m 20s	remaining: 17.4s
# 822:	learn: 0.2439671	total: 1m 20s	remaining: 17.3s
# 823:	learn: 0.2439379	total: 1m 20s	remaining: 17.2s
# 824:	learn: 0.2439131	total: 1m 20s	remaining: 17.1s
# 825:	learn: 0.2438786	total: 1m 20s	remaining: 17s
# 826:	learn: 0.2438571	total: 1m 21s	remaining: 16.9s
# 827:	learn: 0.2438301	total: 1m 21s	remaining: 16.8s
# 828:	learn: 0.2437923	total: 1m 21s	remaining: 16.8s
# 829:	learn: 0.2437584	total: 1m 21s	remaining: 16.7s
# 830:	learn: 0.2437313	total: 1m 21s	remaining: 16.6s
# 831:	learn: 0.2436936	total: 1m 21s	remaining: 16.5s
# 832:	learn: 0.2436647	total: 1m 21s	remaining: 16.4s
# 833:	learn: 0.2436288	total: 1m 21s	remaining: 16.3s
# 834:	learn: 0.2435901	total: 1m 21s	remaining: 16.2s
# 835:	learn: 0.2435669	total: 1m 21s	remaining: 16.1s
# 836:	learn: 0.2432936	total: 1m 21s	remaining: 16s
# 837:	learn: 0.2428638	total: 1m 22s	remaining: 15.9s
# 838:	learn: 0.2428032	total: 1m 22s	remaining: 15.8s
# 839:	learn: 0.2427771	total: 1m 22s	remaining: 15.7s
# 840:	learn: 0.2427515	total: 1m 22s	remaining: 15.6s
# 841:	learn: 0.2427260	total: 1m 22s	remaining: 15.5s
# 842:	learn: 0.2426993	total: 1m 22s	remaining: 15.4s
# 843:	learn: 0.2426690	total: 1m 22s	remaining: 15.3s
# 844:	learn: 0.2426478	total: 1m 22s	remaining: 15.2s
# 845:	learn: 0.2426150	total: 1m 22s	remaining: 15.1s
# 846:	learn: 0.2425877	total: 1m 22s	remaining: 15s
# 847:	learn: 0.2425598	total: 1m 22s	remaining: 14.9s
# 848:	learn: 0.2420007	total: 1m 23s	remaining: 14.8s
# 849:	learn: 0.2419641	total: 1m 23s	remaining: 14.7s
# 850:	learn: 0.2419427	total: 1m 23s	remaining: 14.6s
# 851:	learn: 0.2419092	total: 1m 23s	remaining: 14.5s
# 852:	learn: 0.2418729	total: 1m 23s	remaining: 14.4s
# 853:	learn: 0.2418396	total: 1m 23s	remaining: 14.3s
# 854:	learn: 0.2418146	total: 1m 23s	remaining: 14.2s
# 855:	learn: 0.2417777	total: 1m 23s	remaining: 14.1s
# 856:	learn: 0.2417229	total: 1m 23s	remaining: 14s
# 857:	learn: 0.2416936	total: 1m 23s	remaining: 13.9s
# 858:	learn: 0.2416731	total: 1m 24s	remaining: 13.8s
# 859:	learn: 0.2416451	total: 1m 24s	remaining: 13.7s
# 860:	learn: 0.2416121	total: 1m 24s	remaining: 13.6s
# 861:	learn: 0.2415805	total: 1m 24s	remaining: 13.5s
# 862:	learn: 0.2415471	total: 1m 24s	remaining: 13.4s
# 863:	learn: 0.2415150	total: 1m 24s	remaining: 13.3s
# 864:	learn: 0.2414834	total: 1m 24s	remaining: 13.2s
# 865:	learn: 0.2414611	total: 1m 24s	remaining: 13.1s
# 866:	learn: 0.2414360	total: 1m 24s	remaining: 13s
# 867:	learn: 0.2414026	total: 1m 24s	remaining: 12.9s
# 868:	learn: 0.2413283	total: 1m 24s	remaining: 12.8s
# 869:	learn: 0.2406405	total: 1m 25s	remaining: 12.7s
# 870:	learn: 0.2406036	total: 1m 25s	remaining: 12.6s
# 871:	learn: 0.2405658	total: 1m 25s	remaining: 12.5s
# 872:	learn: 0.2402274	total: 1m 25s	remaining: 12.4s
# 873:	learn: 0.2401916	total: 1m 25s	remaining: 12.3s
# 874:	learn: 0.2396924	total: 1m 25s	remaining: 12.2s
# 875:	learn: 0.2396722	total: 1m 25s	remaining: 12.1s
# 876:	learn: 0.2396490	total: 1m 25s	remaining: 12s
# 877:	learn: 0.2386805	total: 1m 25s	remaining: 11.9s
# 878:	learn: 0.2386590	total: 1m 25s	remaining: 11.8s
# 879:	learn: 0.2382614	total: 1m 26s	remaining: 11.7s
# 880:	learn: 0.2382317	total: 1m 26s	remaining: 11.6s
# 881:	learn: 0.2382009	total: 1m 26s	remaining: 11.5s
# 882:	learn: 0.2381642	total: 1m 26s	remaining: 11.4s
# 883:	learn: 0.2381326	total: 1m 26s	remaining: 11.3s
# 884:	learn: 0.2381090	total: 1m 26s	remaining: 11.2s
# 885:	learn: 0.2380869	total: 1m 26s	remaining: 11.1s
# 886:	learn: 0.2380580	total: 1m 26s	remaining: 11s
# 887:	learn: 0.2380343	total: 1m 26s	remaining: 11s
# 888:	learn: 0.2380103	total: 1m 26s	remaining: 10.9s
# 889:	learn: 0.2379888	total: 1m 27s	remaining: 10.8s
# 890:	learn: 0.2379635	total: 1m 27s	remaining: 10.7s
# 891:	learn: 0.2379419	total: 1m 27s	remaining: 10.6s
# 892:	learn: 0.2379106	total: 1m 27s	remaining: 10.5s
# 893:	learn: 0.2378783	total: 1m 27s	remaining: 10.4s
# 894:	learn: 0.2378570	total: 1m 27s	remaining: 10.3s
# 895:	learn: 0.2378312	total: 1m 27s	remaining: 10.2s
# 896:	learn: 0.2377885	total: 1m 27s	remaining: 10.1s
# 897:	learn: 0.2377612	total: 1m 27s	remaining: 9.97s
# 898:	learn: 0.2377272	total: 1m 27s	remaining: 9.87s
# 899:	learn: 0.2373065	total: 1m 27s	remaining: 9.77s
# 900:	learn: 0.2372827	total: 1m 28s	remaining: 9.67s
# 901:	learn: 0.2372490	total: 1m 28s	remaining: 9.57s
# 902:	learn: 0.2372235	total: 1m 28s	remaining: 9.47s
# 903:	learn: 0.2371926	total: 1m 28s	remaining: 9.38s
# 904:	learn: 0.2368657	total: 1m 28s	remaining: 9.28s
# 905:	learn: 0.2368400	total: 1m 28s	remaining: 9.18s
# 906:	learn: 0.2368133	total: 1m 28s	remaining: 9.08s
# 907:	learn: 0.2367851	total: 1m 28s	remaining: 8.98s
# 908:	learn: 0.2367438	total: 1m 28s	remaining: 8.89s
# 909:	learn: 0.2367078	total: 1m 28s	remaining: 8.79s
# 910:	learn: 0.2366637	total: 1m 28s	remaining: 8.69s
# ...
# 740:	learn: 0.2473765	total: 1m 26s	remaining: 30.4s
# 741:	learn: 0.2473549	total: 1m 27s	remaining: 30.3s
# 742:	learn: 0.2473133	total: 1m 27s	remaining: 30.2s
# 743:	learn: 0.2472528	total: 1m 27s	remaining: 30s
# 744:	learn: 0.2472153	total: 1m 27s	remaining: 29.9s
# 745:	learn: 0.2471772	total: 1m 27s	remaining: 29.8s
# 746:	learn: 0.2471391	total: 1m 27s	remaining: 29.7s
# 747:	learn: 0.2471093	total: 1m 27s	remaining: 29.6s
# 748:	learn: 0.2470903	total: 1m 27s	remaining: 29.4s
# 749:	learn: 0.2466725	total: 1m 28s	remaining: 29.3s
# 750:	learn: 0.2466326	total: 1m 28s	remaining: 29.2s
# 751:	learn: 0.2463782	total: 1m 28s	remaining: 29.1s
# 752:	learn: 0.2463428	total: 1m 28s	remaining: 29s
# 753:	learn: 0.2463200	total: 1m 28s	remaining: 28.9s
# 754:	learn: 0.2462906	total: 1m 28s	remaining: 28.7s
# 755:	learn: 0.2462276	total: 1m 28s	remaining: 28.6s
# 756:	learn: 0.2461978	total: 1m 28s	remaining: 28.5s
# 757:	learn: 0.2461756	total: 1m 28s	remaining: 28.4s
# 758:	learn: 0.2461519	total: 1m 28s	remaining: 28.2s
# 759:	learn: 0.2461228	total: 1m 29s	remaining: 28.1s
# 760:	learn: 0.2460964	total: 1m 29s	remaining: 28s
# 761:	learn: 0.2460757	total: 1m 29s	remaining: 27.9s
# 762:	learn: 0.2460341	total: 1m 29s	remaining: 27.8s
# 763:	learn: 0.2460045	total: 1m 29s	remaining: 27.6s
# 764:	learn: 0.2459850	total: 1m 29s	remaining: 27.5s
# 765:	learn: 0.2459631	total: 1m 29s	remaining: 27.4s
# 766:	learn: 0.2459334	total: 1m 29s	remaining: 27.3s
# 767:	learn: 0.2459093	total: 1m 29s	remaining: 27.2s
# 768:	learn: 0.2458837	total: 1m 30s	remaining: 27s
# 769:	learn: 0.2456361	total: 1m 30s	remaining: 26.9s
# 770:	learn: 0.2456042	total: 1m 30s	remaining: 26.8s
# 771:	learn: 0.2455822	total: 1m 30s	remaining: 26.7s
# 772:	learn: 0.2455598	total: 1m 30s	remaining: 26.6s
# 773:	learn: 0.2452820	total: 1m 30s	remaining: 26.4s
# 774:	learn: 0.2452546	total: 1m 30s	remaining: 26.3s
# 775:	learn: 0.2452282	total: 1m 30s	remaining: 26.2s
# 776:	learn: 0.2451936	total: 1m 30s	remaining: 26.1s
# 777:	learn: 0.2451721	total: 1m 30s	remaining: 26s
# 778:	learn: 0.2451494	total: 1m 31s	remaining: 25.8s
# 779:	learn: 0.2451206	total: 1m 31s	remaining: 25.7s
# 780:	learn: 0.2450819	total: 1m 31s	remaining: 25.6s
# 781:	learn: 0.2450553	total: 1m 31s	remaining: 25.5s
# 782:	learn: 0.2450283	total: 1m 31s	remaining: 25.4s
# 783:	learn: 0.2450031	total: 1m 31s	remaining: 25.2s
# 784:	learn: 0.2449828	total: 1m 31s	remaining: 25.1s
# 785:	learn: 0.2449470	total: 1m 31s	remaining: 25s
# 786:	learn: 0.2449224	total: 1m 31s	remaining: 24.9s
# 787:	learn: 0.2448930	total: 1m 32s	remaining: 24.8s
# 788:	learn: 0.2448675	total: 1m 32s	remaining: 24.6s
# 789:	learn: 0.2448463	total: 1m 32s	remaining: 24.5s
# 790:	learn: 0.2448166	total: 1m 32s	remaining: 24.4s
# 791:	learn: 0.2447725	total: 1m 32s	remaining: 24.3s
# 792:	learn: 0.2444951	total: 1m 32s	remaining: 24.2s
# 793:	learn: 0.2444658	total: 1m 32s	remaining: 24s
# 794:	learn: 0.2444381	total: 1m 32s	remaining: 23.9s
# 795:	learn: 0.2443959	total: 1m 32s	remaining: 23.8s
# 796:	learn: 0.2443642	total: 1m 32s	remaining: 23.7s
# 797:	learn: 0.2443318	total: 1m 33s	remaining: 23.6s
# 798:	learn: 0.2443056	total: 1m 33s	remaining: 23.4s
# 799:	learn: 0.2442757	total: 1m 33s	remaining: 23.3s
# 800:	learn: 0.2442367	total: 1m 33s	remaining: 23.2s
# 801:	learn: 0.2442037	total: 1m 33s	remaining: 23.1s
# 802:	learn: 0.2441765	total: 1m 33s	remaining: 23s
# 803:	learn: 0.2441581	total: 1m 33s	remaining: 22.9s
# 804:	learn: 0.2441355	total: 1m 33s	remaining: 22.7s
# 805:	learn: 0.2440980	total: 1m 33s	remaining: 22.6s
# 806:	learn: 0.2440592	total: 1m 34s	remaining: 22.5s
# 807:	learn: 0.2440364	total: 1m 34s	remaining: 22.4s
# 808:	learn: 0.2440147	total: 1m 34s	remaining: 22.3s
# 809:	learn: 0.2439802	total: 1m 34s	remaining: 22.1s
# 810:	learn: 0.2436784	total: 1m 34s	remaining: 22s
# 811:	learn: 0.2436568	total: 1m 34s	remaining: 21.9s
# 812:	learn: 0.2436333	total: 1m 34s	remaining: 21.8s
# 813:	learn: 0.2436126	total: 1m 34s	remaining: 21.7s
# 814:	learn: 0.2435859	total: 1m 34s	remaining: 21.5s
# 815:	learn: 0.2435237	total: 1m 35s	remaining: 21.4s
# 816:	learn: 0.2434940	total: 1m 35s	remaining: 21.3s
# 817:	learn: 0.2434450	total: 1m 35s	remaining: 21.2s
# 818:	learn: 0.2433985	total: 1m 35s	remaining: 21.1s
# 819:	learn: 0.2433792	total: 1m 35s	remaining: 21s
# 820:	learn: 0.2431199	total: 1m 35s	remaining: 20.8s
# 821:	learn: 0.2430969	total: 1m 35s	remaining: 20.7s
# 822:	learn: 0.2430316	total: 1m 35s	remaining: 20.6s
# 823:	learn: 0.2429166	total: 1m 35s	remaining: 20.5s
# 824:	learn: 0.2428853	total: 1m 35s	remaining: 20.4s
# 825:	learn: 0.2428553	total: 1m 36s	remaining: 20.2s
# 826:	learn: 0.2427568	total: 1m 36s	remaining: 20.1s
# 827:	learn: 0.2427120	total: 1m 36s	remaining: 20s
# 828:	learn: 0.2426581	total: 1m 36s	remaining: 19.9s
# 829:	learn: 0.2426279	total: 1m 36s	remaining: 19.8s
# 830:	learn: 0.2426079	total: 1m 36s	remaining: 19.6s
# 831:	learn: 0.2425584	total: 1m 36s	remaining: 19.5s
# 832:	learn: 0.2425150	total: 1m 36s	remaining: 19.4s
# 833:	learn: 0.2422091	total: 1m 36s	remaining: 19.3s
# 834:	learn: 0.2419127	total: 1m 37s	remaining: 19.2s
# 835:	learn: 0.2415934	total: 1m 37s	remaining: 19.1s
# 836:	learn: 0.2415698	total: 1m 37s	remaining: 18.9s
# 837:	learn: 0.2415382	total: 1m 37s	remaining: 18.8s
# 838:	learn: 0.2415170	total: 1m 37s	remaining: 18.7s
# 839:	learn: 0.2414859	total: 1m 37s	remaining: 18.6s
# 840:	learn: 0.2414619	total: 1m 37s	remaining: 18.5s
# 841:	learn: 0.2411775	total: 1m 37s	remaining: 18.3s
# 842:	learn: 0.2411564	total: 1m 37s	remaining: 18.2s
# 843:	learn: 0.2411205	total: 1m 37s	remaining: 18.1s
# 844:	learn: 0.2410950	total: 1m 38s	remaining: 18s
# 845:	learn: 0.2410696	total: 1m 38s	remaining: 17.9s
# 846:	learn: 0.2410371	total: 1m 38s	remaining: 17.8s
# 847:	learn: 0.2410051	total: 1m 38s	remaining: 17.6s
# 848:	learn: 0.2409573	total: 1m 38s	remaining: 17.5s
# 849:	learn: 0.2409290	total: 1m 38s	remaining: 17.4s
# 850:	learn: 0.2406204	total: 1m 38s	remaining: 17.3s
# 851:	learn: 0.2405957	total: 1m 38s	remaining: 17.2s
# 852:	learn: 0.2405724	total: 1m 38s	remaining: 17.1s
# 853:	learn: 0.2405472	total: 1m 39s	remaining: 16.9s
# 854:	learn: 0.2405272	total: 1m 39s	remaining: 16.8s
# 855:	learn: 0.2404971	total: 1m 39s	remaining: 16.7s
# 856:	learn: 0.2404697	total: 1m 39s	remaining: 16.6s
# 857:	learn: 0.2402321	total: 1m 39s	remaining: 16.5s
# 858:	learn: 0.2402107	total: 1m 39s	remaining: 16.3s
# 859:	learn: 0.2401534	total: 1m 39s	remaining: 16.2s
# 860:	learn: 0.2401177	total: 1m 39s	remaining: 16.1s
# 861:	learn: 0.2400976	total: 1m 39s	remaining: 16s
# 862:	learn: 0.2400720	total: 1m 40s	remaining: 15.9s
# 863:	learn: 0.2400485	total: 1m 40s	remaining: 15.8s
# 864:	learn: 0.2400181	total: 1m 40s	remaining: 15.6s
# 865:	learn: 0.2399927	total: 1m 40s	remaining: 15.5s
# 866:	learn: 0.2399667	total: 1m 40s	remaining: 15.4s
# 867:	learn: 0.2399437	total: 1m 40s	remaining: 15.3s
# 868:	learn: 0.2399251	total: 1m 40s	remaining: 15.2s
# 869:	learn: 0.2398906	total: 1m 40s	remaining: 15.1s
# 870:	learn: 0.2398706	total: 1m 40s	remaining: 14.9s
# 871:	learn: 0.2398522	total: 1m 40s	remaining: 14.8s
# 872:	learn: 0.2398237	total: 1m 41s	remaining: 14.7s
# 873:	learn: 0.2397855	total: 1m 41s	remaining: 14.6s
# 874:	learn: 0.2397414	total: 1m 41s	remaining: 14.5s
# 875:	learn: 0.2397177	total: 1m 41s	remaining: 14.4s
# 876:	learn: 0.2396922	total: 1m 41s	remaining: 14.2s
# 877:	learn: 0.2396582	total: 1m 41s	remaining: 14.1s
# 878:	learn: 0.2396392	total: 1m 41s	remaining: 14s
# 879:	learn: 0.2395829	total: 1m 41s	remaining: 13.9s
# 880:	learn: 0.2395576	total: 1m 41s	remaining: 13.8s
# 881:	learn: 0.2395358	total: 1m 42s	remaining: 13.7s
# 882:	learn: 0.2395067	total: 1m 42s	remaining: 13.5s
# 883:	learn: 0.2392366	total: 1m 42s	remaining: 13.4s
# 884:	learn: 0.2391901	total: 1m 42s	remaining: 13.3s
# 885:	learn: 0.2391574	total: 1m 42s	remaining: 13.2s
# 886:	learn: 0.2391295	total: 1m 42s	remaining: 13.1s
# 887:	learn: 0.2391064	total: 1m 42s	remaining: 13s
# 888:	learn: 0.2390832	total: 1m 42s	remaining: 12.8s
# 889:	learn: 0.2390596	total: 1m 42s	remaining: 12.7s
# 890:	learn: 0.2388400	total: 1m 43s	remaining: 12.6s
# 891:	learn: 0.2388134	total: 1m 43s	remaining: 12.5s
# 892:	learn: 0.2387891	total: 1m 43s	remaining: 12.4s
# 893:	learn: 0.2387585	total: 1m 43s	remaining: 12.3s
# 894:	learn: 0.2387359	total: 1m 43s	remaining: 12.1s
# 895:	learn: 0.2387108	total: 1m 43s	remaining: 12s
# 896:	learn: 0.2386712	total: 1m 43s	remaining: 11.9s
# 897:	learn: 0.2386483	total: 1m 43s	remaining: 11.8s
# 898:	learn: 0.2385860	total: 1m 43s	remaining: 11.7s
# 899:	learn: 0.2385643	total: 1m 43s	remaining: 11.6s
# 900:	learn: 0.2385415	total: 1m 44s	remaining: 11.4s
# 901:	learn: 0.2385000	total: 1m 44s	remaining: 11.3s
# 902:	learn: 0.2384722	total: 1m 44s	remaining: 11.2s
# 903:	learn: 0.2384498	total: 1m 44s	remaining: 11.1s
# 904:	learn: 0.2384324	total: 1m 44s	remaining: 11s
# 905:	learn: 0.2384082	total: 1m 44s	remaining: 10.9s
# 906:	learn: 0.2383817	total: 1m 44s	remaining: 10.7s
# 907:	learn: 0.2383643	total: 1m 44s	remaining: 10.6s
# 908:	learn: 0.2383152	total: 1m 44s	remaining: 10.5s
# 909:	learn: 0.2382820	total: 1m 45s	remaining: 10.4s
# 910:	learn: 0.2382601	total: 1m 45s	remaining: 10.3s
# 911:	learn: 0.2378414	total: 1m 45s	remaining: 10.2s
# 912:	learn: 0.2378213	total: 1m 45s	remaining: 10s
# 913:	learn: 0.2377945	total: 1m 45s	remaining: 9.93s
# 914:	learn: 0.2377589	total: 1m 45s	remaining: 9.81s
# 915:	learn: 0.2377360	total: 1m 45s	remaining: 9.69s
# 916:	learn: 0.2375437	total: 1m 45s	remaining: 9.58s
# 917:	learn: 0.2375189	total: 1m 45s	remaining: 9.46s
# 918:	learn: 0.2374906	total: 1m 46s	remaining: 9.35s
# 919:	learn: 0.2374719	total: 1m 46s	remaining: 9.23s
# 920:	learn: 0.2372744	total: 1m 46s	remaining: 9.11s
# 921:	learn: 0.2372421	total: 1m 46s	remaining: 9s
# 922:	learn: 0.2371901	total: 1m 46s	remaining: 8.88s
# 923:	learn: 0.2368061	total: 1m 46s	remaining: 8.76s
# 924:	learn: 0.2367843	total: 1m 46s	remaining: 8.65s
# 925:	learn: 0.2367534	total: 1m 46s	remaining: 8.53s
# 926:	learn: 0.2367299	total: 1m 46s	remaining: 8.42s
# 927:	learn: 0.2367052	total: 1m 46s	remaining: 8.3s
# 928:	learn: 0.2366790	total: 1m 47s	remaining: 8.18s
# 929:	learn: 0.2365961	total: 1m 47s	remaining: 8.07s
# 930:	learn: 0.2365651	total: 1m 47s	remaining: 7.95s
# 931:	learn: 0.2365252	total: 1m 47s	remaining: 7.84s
# 932:	learn: 0.2365074	total: 1m 47s	remaining: 7.72s
# 933:	learn: 0.2364845	total: 1m 47s	remaining: 7.61s
# 934:	learn: 0.2364519	total: 1m 47s	remaining: 7.49s
# 935:	learn: 0.2364169	total: 1m 47s	remaining: 7.37s
# 936:	learn: 0.2363884	total: 1m 47s	remaining: 7.26s
# 937:	learn: 0.2363452	total: 1m 48s	remaining: 7.14s
# 938:	learn: 0.2363095	total: 1m 48s	remaining: 7.03s
# 939:	learn: 0.2362742	total: 1m 48s	remaining: 6.91s
# 940:	learn: 0.2362508	total: 1m 48s	remaining: 6.79s
# 941:	learn: 0.2362030	total: 1m 48s	remaining: 6.68s
# 942:	learn: 0.2361807	total: 1m 48s	remaining: 6.56s
# 943:	learn: 0.2361610	total: 1m 48s	remaining: 6.45s
# 944:	learn: 0.2361408	total: 1m 48s	remaining: 6.33s
# 945:	learn: 0.2361135	total: 1m 48s	remaining: 6.22s
# 946:	learn: 0.2360729	total: 1m 49s	remaining: 6.1s
# 947:	learn: 0.2360179	total: 1m 49s	remaining: 5.99s
# 948:	learn: 0.2359843	total: 1m 49s	remaining: 5.87s
# 949:	learn: 0.2359508	total: 1m 49s	remaining: 5.75s
# 950:	learn: 0.2359288	total: 1m 49s	remaining: 5.64s
# 951:	learn: 0.2359059	total: 1m 49s	remaining: 5.52s
# 952:	learn: 0.2358800	total: 1m 49s	remaining: 5.41s
# 953:	learn: 0.2358605	total: 1m 49s	remaining: 5.29s
# 954:	learn: 0.2358382	total: 1m 49s	remaining: 5.18s
# 955:	learn: 0.2358148	total: 1m 49s	remaining: 5.06s
# 956:	learn: 0.2357905	total: 1m 50s	remaining: 4.95s
# 957:	learn: 0.2356618	total: 1m 50s	remaining: 4.83s
# 958:	learn: 0.2356210	total: 1m 50s	remaining: 4.72s
# 959:	learn: 0.2355944	total: 1m 50s	remaining: 4.6s
# 960:	learn: 0.2355710	total: 1m 50s	remaining: 4.49s
# 961:	learn: 0.2355325	total: 1m 50s	remaining: 4.37s
# 962:	learn: 0.2354941	total: 1m 50s	remaining: 4.25s
# 963:	learn: 0.2354688	total: 1m 50s	remaining: 4.14s
# 964:	learn: 0.2354417	total: 1m 50s	remaining: 4.02s
# 965:	learn: 0.2354114	total: 1m 51s	remaining: 3.91s
# 966:	learn: 0.2353928	total: 1m 51s	remaining: 3.79s
# 967:	learn: 0.2353679	total: 1m 51s	remaining: 3.68s
# 968:	learn: 0.2353380	total: 1m 51s	remaining: 3.56s
# 969:	learn: 0.2353121	total: 1m 51s	remaining: 3.45s
# 970:	learn: 0.2352928	total: 1m 51s	remaining: 3.33s
# 971:	learn: 0.2352764	total: 1m 51s	remaining: 3.22s
# 972:	learn: 0.2352503	total: 1m 51s	remaining: 3.1s
# 973:	learn: 0.2352197	total: 1m 51s	remaining: 2.99s
# 974:	learn: 0.2351882	total: 1m 52s	remaining: 2.87s
# 975:	learn: 0.2349677	total: 1m 52s	remaining: 2.76s
# 976:	learn: 0.2349468	total: 1m 52s	remaining: 2.64s
# 977:	learn: 0.2349167	total: 1m 52s	remaining: 2.53s
# 978:	learn: 0.2348944	total: 1m 52s	remaining: 2.41s
# 979:	learn: 0.2348650	total: 1m 52s	remaining: 2.3s
# 980:	learn: 0.2348395	total: 1m 52s	remaining: 2.18s
# 981:	learn: 0.2348148	total: 1m 52s	remaining: 2.07s
# 982:	learn: 0.2347908	total: 1m 52s	remaining: 1.95s
# 983:	learn: 0.2347693	total: 1m 52s	remaining: 1.84s
# 984:	learn: 0.2347402	total: 1m 53s	remaining: 1.72s
# 985:	learn: 0.2347217	total: 1m 53s	remaining: 1.61s
# 986:	learn: 0.2347034	total: 1m 53s	remaining: 1.49s
# 987:	learn: 0.2346828	total: 1m 53s	remaining: 1.38s
# 988:	learn: 0.2346625	total: 1m 53s	remaining: 1.26s
# 989:	learn: 0.2346222	total: 1m 53s	remaining: 1.15s
# 990:	learn: 0.2346025	total: 1m 53s	remaining: 1.03s
# 991:	learn: 0.2345822	total: 1m 53s	remaining: 918ms
# 992:	learn: 0.2345607	total: 1m 53s	remaining: 803ms
# 993:	learn: 0.2345427	total: 1m 54s	remaining: 688ms
# 994:	learn: 0.2345147	total: 1m 54s	remaining: 574ms
# 995:	learn: 0.2344822	total: 1m 54s	remaining: 459ms
# 996:	learn: 0.2344549	total: 1m 54s	remaining: 344ms
# 997:	learn: 0.2341971	total: 1m 54s	remaining: 229ms
# 998:	learn: 0.2341623	total: 1m 54s	remaining: 115ms
# 999:	learn: 0.2339600	total: 1m 54s	remaining: 0us
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('input',
#                                         PipelineHelper(available_models={'universal_sentence_tfid': FeatureUnion(n_jobs=None,
#                                                                                                                  transformer_list=[('universal_sentence',
#                                                                                                                                     UniversalEncoderVectorizer()),
#                                                                                                                                    ('tfidf',
#                                                                                                                                     TfidfVectorizer(analyzer='word',
#                                                                                                                                                     binary=False,
#                                                                                                                                                     decode_error='strict',
#                                                                                                                                                     dtype=<class 'numpy.float64'>,
#                                                                                                                                                     encoding='...
#                                         PipelineHelper(available_models={'catboost': <catboost.core.CatBoostClassifier object at 0x7f2f7aad3be0>},
#                                                        optional=False,
#                                                        selected_model=None))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=1,
#              param_grid={'clf__selected_model': [('catboost', {})],
#                          'input__selected_model': [('universal_sentence_tfid',
#                                                     {})]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
overviewCSV = dataDIR + '/results/overview_xboost.csv'

from IPython.display import display

results_df = pd.DataFrame(grid_search.cv_results_).sort_values(by='rank_test_score')
display(results_df)
results_df.to_csv(overviewCSV,index=False)
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0     154.096808      0.914158  ...        0.001589                1
#
# [1 rows x 15 columns]

# %%
bestCSV = dataDIR + '/results/best_perf.csv'

best_est = grid_search.best_estimator_
predictions = best_est.predict(test_df['body'])

best_df = pd.DataFrame(data = zip(test_df['id'],le.inverse_transform(predictions)) ,columns = ['id','subreddit'])

display(best_df)
best_df.to_csv(bestCSV,index=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:289: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#         id    subreddit
# 0        0  datascience
# 1        1        anime
# 2        2          rpg
# 3        3    computers
# 4        4    computers
# ...    ...          ...
# 2893  2893  datascience
# 2894  2894          rpg
# 2895  2895      gamedev
# 2896  2896         cars
# 2897  2897  datascience
#
# [2898 rows x 2 columns]

# %%
predictions
# Out:
# array([[3],
#        [0],
#        [7],
#        ...,
#        [4],
#        [1],
#        [3]])
